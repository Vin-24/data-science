# %%
Assumption
Observation
Inference
Conclusion

# %%
# Open Command prompt --->  pip install pandas
import pandas as pd

# %%
l = list('ABCDE')
l
# Out:
# ['A', 'B', 'C', 'D', 'E']

# %%
a = pd.Series(l)
a
# Out:
# 0    A
# 1    B
# 2    C
# 3    D
# 4    E
# dtype: object

# %%
names = ('Anurag', 'Parn', 'Rupak', 4, 'Saurabh')
names
# Out:
# ('Anurag', 'Parn', 'Rupak', 4, 'Saurabh')

# %%
b = pd.Series(l, index = names)
b
# Out:
# Anurag     A
# Parn       B
# Rupak      C
# 4          D
# Saurabh    E
# dtype: object

# %%
# pd.Series?

# %%
b.ndim
# Out:
# 1

# %%
type(b)
# Out:
# pandas.core.series.Series

# %%
b.dtype
# Out:
# dtype('O')

# %%
b.size
# Out:
# 5

# %%
b.shape
# Out:
# (5,)

# %%
a
# Out:
# 0    A
# 1    B
# 2    C
# 3    D
# 4    E
# dtype: object

# %%
b
# Out:
# Anurag     A
# Parn       B
# Rupak      C
# 4          D
# Saurabh    E
# dtype: object

# %%
a[0]
# Out:
# 'A'

# %%
b['Anurag']
# Out:
# 'A'

# %%
a.loc[0]
# Out:
# 'A'

# %%
b.loc['Anurag']
# Out:
# 'A'

# %%
b.iloc[0]
# Out:
# 'A'

# %%
l
# Out:
# ['A', 'B', 'C', 'D', 'E']

# %%
c = pd.DataFrame(l)
c
# Out:
#    0
# 0  A
# 1  B
# 2  C
# 3  D
# 4  E

# %%
l2 = [['A', 1],
      ['B', 2], 
      ['C', 3]]
l2
# Out:
# [['A', 1], ['B', 2], ['C', 3]]

# %%
pd.DataFrame(l2)
# Out:
#    0  1
# 0  A  1
# 1  B  2
# 2  C  3

# %%
ln = [l, names]
ln
# Out:
# [['A', 'B', 'C', 'D', 'E'], ('Anurag', 'Parn', 'Rupak', 4, 'Saurabh')]

# %%
pd.DataFrame(ln).T
# Out:
#    0        1
# 0  A   Anurag
# 1  B     Parn
# 2  C    Rupak
# 3  D        4
# 4  E  Saurabh

# %%
lz = list(zip(l, names))
lz
# Out:
# [('A', 'Anurag'), ('B', 'Parn'), ('C', 'Rupak'), ('D', 4), ('E', 'Saurabh')]

# %%
pd.DataFrame(lz)
# Out:
#    0        1
# 0  A   Anurag
# 1  B     Parn
# 2  C    Rupak
# 3  D        4
# 4  E  Saurabh

# %%
l
# Out:
# ['A', 'B', 'C', 'D', 'E']

# %%
names
# Out:
# ('Anurag', 'Parn', 'Rupak', 4, 'Saurabh')

# %%
li = []
for x in range(min(len(l), len(names))):
    innerL = [l[x], names[x]]
    li.append(innerL)
li
# Out:
# [['A', 'Anurag'], ['B', 'Parn'], ['C', 'Rupak'], ['D', 4], ['E', 'Saurabh']]

# %%
li = []
for x in range(min(len(l), len(names))):
    innerL = (l[x], names[x])
    li.append(innerL)
li
# Out:
# [('A', 'Anurag'), ('B', 'Parn'), ('C', 'Rupak'), ('D', 4), ('E', 'Saurabh')]

# %%
l2
# Out:
# [['A', 1], ['B', 2], ['C', 3]]

# %%
d2 = pd.DataFrame(l2)
d2
# Out:
#    0  1
# 0  A  1
# 1  B  2
# 2  C  3

# %%
pd.DataFrame(l2, index = range(45, 45 + len(l2)), columns = ['Grade', 'Score'])
# Out:
#    Grade  Score
# 45     A      1
# 46     B      2
# 47     C      3

# %%
a = pd.DataFrame(l2, index = [45, 46, 45], columns = ['Grade', 'Score'])
a
# Out:
#    Grade  Score
# 45     A      1
# 46     B      2
# 45     C      3

# %%
a.loc[45]
# Out:
#    Grade  Score
# 45     A      1
# 45     C      3

# %%
pd.DataFrame(l2, index = range(45, 45 + len(l2)), columns = [chr(i) for i in range(65, 65 + len(l2[0]))])
# Out:
#     A  B
# 45  A  1
# 46  B  2
# 47  C  3

# %%
nl = []
for i in range(65, 65 + len(l2[0])):
    nl.append(chr(i))
nl
# Out:
# ['A', 'B']

# %%
[chr(i) for i in range(65, 65 + len(l2[0]))]
# Out:
# ['A', 'B']

# %%
l2
# Out:
# [['A', 1], ['B', 2], ['C', 3]]

# %%
di = {'Grade':list('ABC'),
     'Score':[1, 2, 3]}
di
# Out:
# {'Grade': ['A', 'B', 'C'], 'Score': [1, 2, 3]}

# %%
d3 = pd.DataFrame(di)
d3
# Out:
#   Grade  Score
# 0     A      1
# 1     B      2
# 2     C      3

# %%
di
# Out:
# {'Grade': ['A', 'B', 'C'], 'Score': [1, 2, 3]}

# %%
di2 = [{'Grade':'A', 'Score':1},
      {'Grade':'B', 'Score':2, 'Age':29},
      {'Grade':'C', 'Score':3}]
di2
# Out:
# [{'Grade': 'A', 'Score': 1},
#  {'Grade': 'B', 'Score': 2, 'Age': 29},
#  {'Grade': 'C', 'Score': 3}]

# %%
d4 = pd.DataFrame(di2)
d4
# Out:
#   Grade  Score   Age
# 0     A      1   NaN
# 1     B      2  29.0
# 2     C      3   NaN

# %%
d3
# Out:
#   Grade  Score
# 0     A      1
# 1     B      2
# 2     C      3

# %%
d4.dtypes
# Out:
# Grade     object
# Score      int64
# Age      float64
# dtype: object

# %%
import numpy as np
di = {'Grade':list('ABC'),
     'Score':[1, 2, 3],
     'Age':[np.nan, 29, np.nan]}
d3 = pd.DataFrame(di)
d3
# Out:
#   Grade  Score   Age
# 0     A      1   NaN
# 1     B      2  29.0
# 2     C      3   NaN

# %%
n = pd.read_csv(r'C:\Users\harsh\Documents\Python Codes\DataSets\nba.csv')
n
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
n
# Out:
#                          Name                    Team  Number Position   Age  \
# 0               Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                 Jae Crowder          Boston Celtics    99.0       SF  25.0
# 2                John Holland          Boston Celtics    30.0       SG  27.0
# 3                 R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4               Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5                Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6               Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7                Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8                Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9                Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10            Jared Sullinger          Boston Celtics     7.0        C  24.0
# ...

# %%
pd.set_option('display.max_rows', 10)

# %%
n
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
# pd.read_excel(r'nba.xlsx')

# %%
air = pd.read_csv(r'https://raw.githubusercontent.com/datasets/airport-codes/master/data/airport-codes.csv')
air
# Out:
#          ident            type                                name  \
# 0          00A        heliport                   Total Rf Heliport
# 1         00AA   small_airport                Aero B Ranch Airport
# 2         00AK   small_airport                        Lowell Field
# 3         00AL   small_airport                        Epps Airpark
# 4         00AR          closed  Newport Hospital & Clinic Heliport
# ...        ...             ...                                 ...
# 55108     ZYYK  medium_airport               Yingkou Lanqi Airport
# 55109     ZYYY  medium_airport             Shenyang Dongta Airport
# 55110  ZZ-0001        heliport                     Sealand Helipad
# 55111  ZZ-0002   small_airport           Glorioso Islands Airstrip
# 55112     ZZZZ   small_airport              Satsuma Iōjima Airport
#
#        elevation_ft continent iso_country iso_region      municipality  \
# 0              11.0       NaN          US      US-PA          Bensalem
# ...

# %%
air.to_csv('air.csv')

# %%
n
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
n1 = n.copy()

# %%
n.shape
# Out:
# (457, 9)

# %% [markdown]
# ## Indexing

# %%
n['Name']      # Single Column Indexing
# Out:
# 0      Avery Bradley
# 1        Jae Crowder
# 2       John Holland
# 3        R.J. Hunter
# 4      Jonas Jerebko
#            ...
# 452       Trey Lyles
# 453     Shelvin Mack
# 454        Raul Neto
# 455     Tibor Pleiss
# 456      Jeff Withey
# Name: Name, Length: 457, dtype: object

# %%
type(n['Name'])
# Out:
# pandas.core.series.Series

# %%
n[['Name', 'College', 'Age']]
# Out:
#               Name            College   Age
# 0    Avery Bradley              Texas  25.0
# 1      Jae Crowder          Marquette  25.0
# 2     John Holland  Boston University  27.0
# 3      R.J. Hunter      Georgia State  22.0
# 4    Jonas Jerebko                NaN  29.0
# ..             ...                ...   ...
# 452     Trey Lyles           Kentucky  20.0
# 453   Shelvin Mack             Butler  26.0
# 454      Raul Neto                NaN  24.0
# 455   Tibor Pleiss                NaN  26.0
# 456    Jeff Withey             Kansas  26.0
#
# [457 rows x 3 columns]

# %%
# Single Row Indexing

n.loc[0]
# Out:
# Name         Avery Bradley
# Team        Boston Celtics
# Number                 0.0
# Position                PG
# Age                   25.0
# Height                 6-2
# Weight               180.0
# College              Texas
# Salary           7730337.0
# Name: 0, dtype: object

# %%
n.loc[[0]]
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
#
#   College     Salary
# 0   Texas  7730337.0

# %%
n
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
# Multi Row Indexing
n.loc[[0, 400, 96]]
# Out:
#               Name                    Team  Number Position   Age Height  \
# 0    Avery Bradley          Boston Celtics     0.0       PG  25.0    6-2
# 400  Kevin Garnett  Minnesota Timberwolves    21.0       PF  40.0   6-11
# 96   Blake Griffin    Los Angeles Clippers    32.0       PF  27.0   6-10
#
#      Weight   College      Salary
# 0     180.0     Texas   7730337.0
# 400   240.0       NaN   8500000.0
# 96    251.0  Oklahoma  18907726.0

# %%
n.loc[[i for i in range(len(n)) if i%3 == 0]]
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 9     Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
# 12     Evan Turner  Boston Celtics    11.0       SG  27.0    6-7   220.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 444     Alec Burks       Utah Jazz    10.0       SG  24.0    6-6   214.0
# 447    Rudy Gobert       Utah Jazz    27.0        C  23.0    7-1   245.0
# 450     Joe Ingles       Utah Jazz     2.0       SF  28.0    6-8   226.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#             College     Salary
# 0             Texas  7730337.0
# ...

# %%
import numpy as np
# np.random.randint(0, 457, (10))
n.loc[np.random.randint(0, 457, (10))]
# Out:
#                   Name                    Team  Number Position   Age Height  \
# 52         Carl Landry      Philadelphia 76ers     7.0       PF  32.0    6-9
# 70       Norman Powell         Toronto Raptors    24.0       SG  23.0    6-4
# 70       Norman Powell         Toronto Raptors    24.0       SG  23.0    6-4
# 145         Duje Dukan        Sacramento Kings    26.0       PF  24.0    6-9
# 187  Spencer Dinwiddie         Detroit Pistons     8.0       PG  23.0    6-6
# 310   Tim Hardaway Jr.           Atlanta Hawks    10.0       SG  24.0    6-6
# 279        Norris Cole    New Orleans Pelicans    30.0       PG  27.0    6-2
# 411     Andrew Wiggins  Minnesota Timberwolves    22.0       SG  21.0    6-8
# 442      Trevor Booker               Utah Jazz    33.0       PF  28.0    6-8
# 150        Rajon Rondo        Sacramento Kings     9.0       PG  30.0    6-1
#
#      Weight          College     Salary
# 52    248.0           Purdue  6500000.0
# 70    215.0             UCLA   650000.0
# ...

# %%
n.sample(5)
# Out:
#               Name                   Team  Number Position   Age Height  \
# 301  Kawhi Leonard      San Antonio Spurs     2.0       SF  24.0    6-7
# 95      Jeff Green   Los Angeles Clippers     8.0       SF  29.0    6-9
# 121   Eric Bledsoe           Phoenix Suns     2.0       PG  26.0    6-1
# 89   Klay Thompson  Golden State Warriors    11.0       SG  26.0    6-7
# 285   Tyreke Evans   New Orleans Pelicans     1.0       SG  26.0    6-6
#
#      Weight           College      Salary
# 301   230.0   San Diego State  16407500.0
# 95    235.0        Georgetown   9650000.0
# 121   190.0          Kentucky  13500000.0
# 89    215.0  Washington State  15501000.0
# 285   220.0           Memphis  10734586.0

# %%
n.head(2)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
#
#      College     Salary
# 0      Texas  7730337.0
# 1  Marquette  6796117.0

# %%
n.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight   College  \
# 452    Trey Lyles  Utah Jazz    41.0       PF  20.0   6-10   234.0  Kentucky
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0    Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0       NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0       NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0    Kansas
#
#         Salary
# 452  2239800.0
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0

# %%
n.loc[45:52]
# Out:
#                 Name                Team  Number Position   Age Height  \
# 45       Tony Wroten     New York Knicks     5.0       SG  23.0    6-6
# 46       Elton Brand  Philadelphia 76ers    42.0       PF  37.0    6-9
# 47     Isaiah Canaan  Philadelphia 76ers     0.0       PG  25.0    6-0
# 48  Robert Covington  Philadelphia 76ers    33.0       SF  25.0    6-9
# 49       Joel Embiid  Philadelphia 76ers    21.0        C  22.0    7-0
# 50      Jerami Grant  Philadelphia 76ers    39.0       SF  22.0    6-8
# 51    Richaun Holmes  Philadelphia 76ers    22.0       PF  22.0   6-10
# 52       Carl Landry  Philadelphia 76ers     7.0       PF  32.0    6-9
#
#     Weight          College     Salary
# 45   205.0       Washington   167406.0
# 46   254.0             Duke        NaN
# 47   201.0     Murray State   947276.0
# 48   215.0  Tennessee State  1000000.0
# 49   250.0           Kansas  4626960.0
# 50   210.0         Syracuse   845059.0
# 51   245.0    Bowling Green  1074169.0
# ...

# %%
n.iloc[45:52]
# Out:
#                 Name                Team  Number Position   Age Height  \
# 45       Tony Wroten     New York Knicks     5.0       SG  23.0    6-6
# 46       Elton Brand  Philadelphia 76ers    42.0       PF  37.0    6-9
# 47     Isaiah Canaan  Philadelphia 76ers     0.0       PG  25.0    6-0
# 48  Robert Covington  Philadelphia 76ers    33.0       SF  25.0    6-9
# 49       Joel Embiid  Philadelphia 76ers    21.0        C  22.0    7-0
# 50      Jerami Grant  Philadelphia 76ers    39.0       SF  22.0    6-8
# 51    Richaun Holmes  Philadelphia 76ers    22.0       PF  22.0   6-10
#
#     Weight          College     Salary
# 45   205.0       Washington   167406.0
# 46   254.0             Duke        NaN
# 47   201.0     Murray State   947276.0
# 48   215.0  Tennessee State  1000000.0
# 49   250.0           Kansas  4626960.0
# 50   210.0         Syracuse   845059.0
# 51   245.0    Bowling Green  1074169.0

# %%
m = pd.read_csv(r'C:\Users\harsh\Documents\Python Codes\DataSets\nba.csv', index_col = 'Name')
m
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ...                       ...     ...      ...   ...    ...     ...
# Trey Lyles          Utah Jazz    41.0       PF  20.0   6-10   234.0
# Shelvin Mack        Utah Jazz     8.0       PG  26.0    6-3   203.0
# Raul Neto           Utah Jazz    25.0       PG  24.0    6-1   179.0
# Tibor Pleiss        Utah Jazz    21.0        C  26.0    7-3   256.0
# Jeff Withey         Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                          College     Salary
# Name
# Avery Bradley              Texas  7730337.0
# Jae Crowder            Marquette  6796117.0
# ...

# %%
m.loc['Avery Bradley']
# Out:
# Team        Boston Celtics
# Number                 0.0
# Position                PG
# Age                   25.0
# Height                 6-2
# Weight               180.0
# College              Texas
# Salary           7730337.0
# Name: Avery Bradley, dtype: object

# %%
n
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
new = n['Name'].str.split(" ")
new
# Out:
# 0      [Avery, Bradley]
# 1        [Jae, Crowder]
# 2       [John, Holland]
# 3        [R.J., Hunter]
# 4      [Jonas, Jerebko]
#              ...
# 452       [Trey, Lyles]
# 453     [Shelvin, Mack]
# 454        [Raul, Neto]
# 455     [Tibor, Pleiss]
# 456      [Jeff, Withey]
# Name: Name, Length: 457, dtype: object

# %%
new1 = n['Name'].str.split(" ", n = 1, expand = True)
new1
# Out:
#            0        1
# 0      Avery  Bradley
# 1        Jae  Crowder
# 2       John  Holland
# 3       R.J.   Hunter
# 4      Jonas  Jerebko
# ..       ...      ...
# 452     Trey    Lyles
# 453  Shelvin     Mack
# 454     Raul     Neto
# 455    Tibor   Pleiss
# 456     Jeff   Withey
#
# [457 rows x 2 columns]

# %%
new1
# Out:
#            0        1
# 0      Avery  Bradley
# 1        Jae  Crowder
# 2       John  Holland
# 3       R.J.   Hunter
# 4      Jonas  Jerebko
# ..       ...      ...
# 452     Trey    Lyles
# 453  Shelvin     Mack
# 454     Raul     Neto
# 455    Tibor   Pleiss
# 456     Jeff   Withey
#
# [457 rows x 2 columns]

# %%
n['firstName'] = new1[0]
n
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary firstName
# 0                Texas  7730337.0     Avery
# ...

# %%
n.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary', 'firstName'],
#       dtype='object')

# %%
n = n[['Name', 'firstName', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
       'College', 'Salary']]

# %%
n
# Out:
#               Name firstName            Team  Number Position   Age Height  \
# 0    Avery Bradley     Avery  Boston Celtics     0.0       PG  25.0    6-2
# 1      Jae Crowder       Jae  Boston Celtics    99.0       SF  25.0    6-6
# 2     John Holland      John  Boston Celtics    30.0       SG  27.0    6-5
# 3      R.J. Hunter      R.J.  Boston Celtics    28.0       SG  22.0    6-5
# 4    Jonas Jerebko     Jonas  Boston Celtics     8.0       PF  29.0   6-10
# ..             ...       ...             ...     ...      ...   ...    ...
# 452     Trey Lyles      Trey       Utah Jazz    41.0       PF  20.0   6-10
# 453   Shelvin Mack   Shelvin       Utah Jazz     8.0       PG  26.0    6-3
# 454      Raul Neto      Raul       Utah Jazz    25.0       PG  24.0    6-1
# 455   Tibor Pleiss     Tibor       Utah Jazz    21.0        C  26.0    7-3
# 456    Jeff Withey      Jeff       Utah Jazz    24.0        C  26.0    7-0
#
#      Weight            College     Salary
# ...

# %%
n.insert(loc = 2, column = 'lastName', value = new1[1])
n
# Out:
#               Name firstName lastName            Team  Number Position   Age  \
# 0    Avery Bradley     Avery  Bradley  Boston Celtics     0.0       PG  25.0
# 1      Jae Crowder       Jae  Crowder  Boston Celtics    99.0       SF  25.0
# 2     John Holland      John  Holland  Boston Celtics    30.0       SG  27.0
# 3      R.J. Hunter      R.J.   Hunter  Boston Celtics    28.0       SG  22.0
# 4    Jonas Jerebko     Jonas  Jerebko  Boston Celtics     8.0       PF  29.0
# ..             ...       ...      ...             ...     ...      ...   ...
# 452     Trey Lyles      Trey    Lyles       Utah Jazz    41.0       PF  20.0
# 453   Shelvin Mack   Shelvin     Mack       Utah Jazz     8.0       PG  26.0
# 454      Raul Neto      Raul     Neto       Utah Jazz    25.0       PG  24.0
# 455   Tibor Pleiss     Tibor   Pleiss       Utah Jazz    21.0        C  26.0
# 456    Jeff Withey      Jeff   Withey       Utah Jazz    24.0        C  26.0
#
# ...

# %%
n
# Out:
#               Name firstName lastName            Team  Number Position   Age  \
# 0    Avery Bradley     Avery  Bradley  Boston Celtics     0.0       PG  25.0
# 1      Jae Crowder       Jae  Crowder  Boston Celtics    99.0       SF  25.0
# 2     John Holland      John  Holland  Boston Celtics    30.0       SG  27.0
# 3      R.J. Hunter      R.J.   Hunter  Boston Celtics    28.0       SG  22.0
# 4    Jonas Jerebko     Jonas  Jerebko  Boston Celtics     8.0       PF  29.0
# ..             ...       ...      ...             ...     ...      ...   ...
# 452     Trey Lyles      Trey    Lyles       Utah Jazz    41.0       PF  20.0
# 453   Shelvin Mack   Shelvin     Mack       Utah Jazz     8.0       PG  26.0
# 454      Raul Neto      Raul     Neto       Utah Jazz    25.0       PG  24.0
# 455   Tibor Pleiss     Tibor   Pleiss       Utah Jazz    21.0        C  26.0
# 456    Jeff Withey      Jeff   Withey       Utah Jazz    24.0        C  26.0
#
# ...

# %%
n['firstName'].loc[453]
# Out:
# 'Shelvin'

# %%
n.loc[[453, 2]]['firstName']
# Out:
# 453    Shelvin
# 2         John
# Name: firstName, dtype: object

# %%
n
# Out:
#               Name firstName lastName            Team  Number Position   Age  \
# 0    Avery Bradley     Avery  Bradley  Boston Celtics     0.0       PG  25.0
# 1      Jae Crowder       Jae  Crowder  Boston Celtics    99.0       SF  25.0
# 2     John Holland      John  Holland  Boston Celtics    30.0       SG  27.0
# 3      R.J. Hunter      R.J.   Hunter  Boston Celtics    28.0       SG  22.0
# 4    Jonas Jerebko     Jonas  Jerebko  Boston Celtics     8.0       PF  29.0
# ..             ...       ...      ...             ...     ...      ...   ...
# 452     Trey Lyles      Trey    Lyles       Utah Jazz    41.0       PF  20.0
# 453   Shelvin Mack   Shelvin     Mack       Utah Jazz     8.0       PG  26.0
# 454      Raul Neto      Raul     Neto       Utah Jazz    25.0       PG  24.0
# 455   Tibor Pleiss     Tibor   Pleiss       Utah Jazz    21.0        C  26.0
# 456    Jeff Withey      Jeff   Withey       Utah Jazz    24.0        C  26.0
#
# ...

# %%
n['firstName'].loc[453] = 'Shivam'
# Out:
# d:\installed softwares\python\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# d:\installed softwares\python\lib\site-packages\pandas\core\indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)

# %%
n
# Out:
#               Name firstName lastName            Team  Number Position   Age  \
# 0    Avery Bradley     Avery  Bradley  Boston Celtics     0.0       PG  25.0
# 1      Jae Crowder       Jae  Crowder  Boston Celtics    99.0       SF  25.0
# 2     John Holland      John  Holland  Boston Celtics    30.0       SG  27.0
# 3      R.J. Hunter      R.J.   Hunter  Boston Celtics    28.0       SG  22.0
# 4    Jonas Jerebko     Jonas  Jerebko  Boston Celtics     8.0       PF  29.0
# ..             ...       ...      ...             ...     ...      ...   ...
# 452     Trey Lyles      Trey    Lyles       Utah Jazz    41.0       PF  20.0
# 453   Shelvin Mack    Shivam     Mack       Utah Jazz     8.0       PG  26.0
# 454      Raul Neto      Raul     Neto       Utah Jazz    25.0       PG  24.0
# 455   Tibor Pleiss     Tibor   Pleiss       Utah Jazz    21.0        C  26.0
# 456    Jeff Withey      Jeff   Withey       Utah Jazz    24.0        C  26.0
#
# ...

# %%
n.at[453, 'firstName'] = 'Bhanu'

# %%
n
# Out:
#               Name firstName lastName            Team  Number Position   Age  \
# 0    Avery Bradley     Avery  Bradley  Boston Celtics     0.0       PG  25.0
# 1      Jae Crowder       Jae  Crowder  Boston Celtics    99.0       SF  25.0
# 2     John Holland      John  Holland  Boston Celtics    30.0       SG  27.0
# 3      R.J. Hunter      R.J.   Hunter  Boston Celtics    28.0       SG  22.0
# 4    Jonas Jerebko     Jonas  Jerebko  Boston Celtics     8.0       PF  29.0
# ..             ...       ...      ...             ...     ...      ...   ...
# 452     Trey Lyles      Trey    Lyles       Utah Jazz    41.0       PF  20.0
# 453   Shelvin Mack    Shivam     Mack       Utah Jazz     8.0       PG  26.0
# 454      Raul Neto      Raul     Neto       Utah Jazz    25.0       PG  24.0
# 455   Tibor Pleiss     Tibor   Pleiss       Utah Jazz    21.0        C  26.0
# 456    Jeff Withey      Jeff   Withey       Utah Jazz    24.0        C  26.0
#
# ...

# %%
n.at[453, 'firstName']
# Out:
# 'Bhanu'

# %%
n
# Out:
#               Name firstName lastName            Team  Number Position   Age  \
# 0    Avery Bradley     Avery  Bradley  Boston Celtics     0.0       PG  25.0
# 1      Jae Crowder       Jae  Crowder  Boston Celtics    99.0       SF  25.0
# 2     John Holland      John  Holland  Boston Celtics    30.0       SG  27.0
# 3      R.J. Hunter      R.J.   Hunter  Boston Celtics    28.0       SG  22.0
# 4    Jonas Jerebko     Jonas  Jerebko  Boston Celtics     8.0       PF  29.0
# ..             ...       ...      ...             ...     ...      ...   ...
# 452     Trey Lyles      Trey    Lyles       Utah Jazz    41.0       PF  20.0
# 453   Shelvin Mack    Shivam     Mack       Utah Jazz     8.0       PG  26.0
# 454      Raul Neto      Raul     Neto       Utah Jazz    25.0       PG  24.0
# 455   Tibor Pleiss     Tibor   Pleiss       Utah Jazz    21.0        C  26.0
# 456    Jeff Withey      Jeff   Withey       Utah Jazz    24.0        C  26.0
#
# ...

# %%
n.iloc[453, 1] = 'Some'
n
# Out:
# d:\installed softwares\python\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#               Name firstName lastName            Team  Number Position   Age  \
# 0    Avery Bradley     Avery  Bradley  Boston Celtics     0.0       PG  25.0
# 1      Jae Crowder       Jae  Crowder  Boston Celtics    99.0       SF  25.0
# 2     John Holland      John  Holland  Boston Celtics    30.0       SG  27.0
# 3      R.J. Hunter      R.J.   Hunter  Boston Celtics    28.0       SG  22.0
# 4    Jonas Jerebko     Jonas  Jerebko  Boston Celtics     8.0       PF  29.0
# ..             ...       ...      ...             ...     ...      ...   ...
# ...

# %%
m.index
# Out:
# Index(['Avery Bradley', 'Jae Crowder', 'John Holland', 'R.J. Hunter',
#        'Jonas Jerebko', 'Amir Johnson', 'Jordan Mickey', 'Kelly Olynyk',
#        'Terry Rozier', 'Marcus Smart',
#        ...
#        'Rudy Gobert', 'Gordon Hayward', 'Rodney Hood', 'Joe Ingles',
#        'Chris Johnson', 'Trey Lyles', 'Shelvin Mack', 'Raul Neto',
#        'Tibor Pleiss', 'Jeff Withey'],
#       dtype='object', name='Name', length=457)

# %%
new1
# Out:
#            0        1
# 0      Avery  Bradley
# 1        Jae  Crowder
# 2       John  Holland
# 3       R.J.   Hunter
# 4      Jonas  Jerebko
# ..       ...      ...
# 452     Trey    Lyles
# 453  Shelvin     Mack
# 454     Raul     Neto
# 455    Tibor   Pleiss
# 456     Jeff   Withey
#
# [457 rows x 2 columns]

# %%
m
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ...                       ...     ...      ...   ...    ...     ...
# Trey Lyles          Utah Jazz    41.0       PF  20.0   6-10   234.0
# Shelvin Mack        Utah Jazz     8.0       PG  26.0    6-3   203.0
# Raul Neto           Utah Jazz    25.0       PG  24.0    6-1   179.0
# Tibor Pleiss        Utah Jazz    21.0        C  26.0    7-3   256.0
# Jeff Withey         Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                          College     Salary
# Name
# Avery Bradley              Texas  7730337.0
# Jae Crowder            Marquette  6796117.0
# ...

# %%
mi = m.index
mi
# Out:
# Index(['Avery Bradley', 'Jae Crowder', 'John Holland', 'R.J. Hunter',
#        'Jonas Jerebko', 'Amir Johnson', 'Jordan Mickey', 'Kelly Olynyk',
#        'Terry Rozier', 'Marcus Smart',
#        ...
#        'Rudy Gobert', 'Gordon Hayward', 'Rodney Hood', 'Joe Ingles',
#        'Chris Johnson', 'Trey Lyles', 'Shelvin Mack', 'Raul Neto',
#        'Tibor Pleiss', 'Jeff Withey'],
#       dtype='object', name='Name', length=457)

# %%
new2 = new1.copy()

# %%
# new2.set_index(m.index, inplace = True)
# new2
new3 = new2.set_index(m.index)
new3
# Out:
#                      0        1
# Name
# Avery Bradley    Avery  Bradley
# Jae Crowder        Jae  Crowder
# John Holland      John  Holland
# R.J. Hunter       R.J.   Hunter
# Jonas Jerebko    Jonas  Jerebko
# ...                ...      ...
# Trey Lyles        Trey    Lyles
# Shelvin Mack   Shelvin     Mack
# Raul Neto         Raul     Neto
# Tibor Pleiss     Tibor   Pleiss
# Jeff Withey       Jeff   Withey
#
# [457 rows x 2 columns]

# %%
new2
# Out:
#            0        1
# 0      Avery  Bradley
# 1        Jae  Crowder
# 2       John  Holland
# 3       R.J.   Hunter
# 4      Jonas  Jerebko
# ..       ...      ...
# 452     Trey    Lyles
# 453  Shelvin     Mack
# 454     Raul     Neto
# 455    Tibor   Pleiss
# 456     Jeff   Withey
#
# [457 rows x 2 columns]

# %%
def func(inplace = False):
    if inplace == True:
        return [1,2,3]

# %%
func(inplace = True)
# Out:
# [1, 2, 3]

# %%
print(func())
# Out:
# None

# %%
new3
# Out:
#                      0        1
# Name
# Avery Bradley    Avery  Bradley
# Jae Crowder        Jae  Crowder
# John Holland      John  Holland
# R.J. Hunter       R.J.   Hunter
# Jonas Jerebko    Jonas  Jerebko
# ...                ...      ...
# Trey Lyles        Trey    Lyles
# Shelvin Mack   Shelvin     Mack
# Raul Neto         Raul     Neto
# Tibor Pleiss     Tibor   Pleiss
# Jeff Withey       Jeff   Withey
#
# [457 rows x 2 columns]

# %%
m
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ...                       ...     ...      ...   ...    ...     ...
# Trey Lyles          Utah Jazz    41.0       PF  20.0   6-10   234.0
# Shelvin Mack        Utah Jazz     8.0       PG  26.0    6-3   203.0
# Raul Neto           Utah Jazz    25.0       PG  24.0    6-1   179.0
# Tibor Pleiss        Utah Jazz    21.0        C  26.0    7-3   256.0
# Jeff Withey         Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                          College     Salary
# Name
# Avery Bradley              Texas  7730337.0
# Jae Crowder            Marquette  6796117.0
# ...

# %%
m['First'] = new3[0]

# %%
m
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ...                       ...     ...      ...   ...    ...     ...
# Trey Lyles          Utah Jazz    41.0       PF  20.0   6-10   234.0
# Shelvin Mack        Utah Jazz     8.0       PG  26.0    6-3   203.0
# Raul Neto           Utah Jazz    25.0       PG  24.0    6-1   179.0
# Tibor Pleiss        Utah Jazz    21.0        C  26.0    7-3   256.0
# Jeff Withey         Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                          College     Salary    First
# Name
# Avery Bradley              Texas  7730337.0    Avery
# ...

# %%
n
# Out:
#               Name firstName lastName            Team  Number Position   Age  \
# 0    Avery Bradley     Avery  Bradley  Boston Celtics     0.0       PG  25.0
# 1      Jae Crowder       Jae  Crowder  Boston Celtics    99.0       SF  25.0
# 2     John Holland      John  Holland  Boston Celtics    30.0       SG  27.0
# 3      R.J. Hunter      R.J.   Hunter  Boston Celtics    28.0       SG  22.0
# 4    Jonas Jerebko     Jonas  Jerebko  Boston Celtics     8.0       PF  29.0
# ..             ...       ...      ...             ...     ...      ...   ...
# 452     Trey Lyles      Trey    Lyles       Utah Jazz    41.0       PF  20.0
# 453   Shelvin Mack      Some     Mack       Utah Jazz     8.0       PG  26.0
# 454      Raul Neto      Raul     Neto       Utah Jazz    25.0       PG  24.0
# 455   Tibor Pleiss     Tibor   Pleiss       Utah Jazz    21.0        C  26.0
# 456    Jeff Withey      Jeff   Withey       Utah Jazz    24.0        C  26.0
#
# ...

# %%
n.drop(columns = ['Name'])
# Out:
#     firstName lastName            Team  Number Position   Age Height  Weight  \
# 0       Avery  Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1         Jae  Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2        John  Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3        R.J.   Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4       Jonas  Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..        ...      ...             ...     ...      ...   ...    ...     ...
# 452      Trey    Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453      Some     Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul     Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455     Tibor   Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456      Jeff   Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# ...

# %%
n
# Out:
#               Name firstName lastName            Team  Number Position   Age  \
# 0    Avery Bradley     Avery  Bradley  Boston Celtics     0.0       PG  25.0
# 1      Jae Crowder       Jae  Crowder  Boston Celtics    99.0       SF  25.0
# 2     John Holland      John  Holland  Boston Celtics    30.0       SG  27.0
# 3      R.J. Hunter      R.J.   Hunter  Boston Celtics    28.0       SG  22.0
# 4    Jonas Jerebko     Jonas  Jerebko  Boston Celtics     8.0       PF  29.0
# ..             ...       ...      ...             ...     ...      ...   ...
# 452     Trey Lyles      Trey    Lyles       Utah Jazz    41.0       PF  20.0
# 453   Shelvin Mack      Some     Mack       Utah Jazz     8.0       PG  26.0
# 454      Raul Neto      Raul     Neto       Utah Jazz    25.0       PG  24.0
# 455   Tibor Pleiss     Tibor   Pleiss       Utah Jazz    21.0        C  26.0
# 456    Jeff Withey      Jeff   Withey       Utah Jazz    24.0        C  26.0
#
# ...

# %%
n.drop(columns = 'Name', inplace = True)

# %%
n
# Out:
#     firstName lastName            Team  Number Position   Age Height  Weight  \
# 0       Avery  Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1         Jae  Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2        John  Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3        R.J.   Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4       Jonas  Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..        ...      ...             ...     ...      ...   ...    ...     ...
# 452      Trey    Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453      Some     Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul     Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455     Tibor   Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456      Jeff   Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# ...

# %%
n.drop(index = 453, inplace = True)
n
# Out:
#     firstName lastName            Team  Number Position   Age Height  Weight  \
# 0       Avery  Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1         Jae  Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2        John  Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3        R.J.   Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4       Jonas  Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..        ...      ...             ...     ...      ...   ...    ...     ...
# 451     Chris  Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452      Trey    Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 454      Raul     Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455     Tibor   Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456      Jeff   Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# ...

# %%
n.drop(index = range(50, 55), inplace = True)

# %%
n
# Out:
#     firstName lastName            Team  Number Position   Age Height  Weight  \
# 0       Avery  Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1         Jae  Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2        John  Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3        R.J.   Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4       Jonas  Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..        ...      ...             ...     ...      ...   ...    ...     ...
# 451     Chris  Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452      Trey    Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 454      Raul     Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455     Tibor   Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456      Jeff   Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# ...

# %%
n2 = n[34:38].drop(columns = ['Team', 'Age'])
n3 = n[127:130].drop(columns = 'Salary')

# %%
n2
# Out:
#      firstName  lastName  Number Position Height  Weight         College  \
# 34        Jose  Calderon     3.0       PG    6-3   200.0             NaN
# 35  Cleanthony     Early    11.0       SF    6-8   210.0   Wichita State
# 36    Langston  Galloway     2.0       SG    6-2   200.0  Saint Joseph's
# 37      Jerian     Grant    13.0       PG    6-4   195.0      Notre Dame
#
#        Salary
# 34  7402812.0
# 35   845059.0
# 36   845059.0
# 37  1572360.0

# %%
n3
# Out:
#     firstName   lastName          Team  Number Position   Age Height  Weight  \
# 132     Mirza  Teletovic  Phoenix Suns    35.0       PF  30.0    6-9   242.0
# 133      P.J.     Tucker  Phoenix Suns    17.0       SF  31.0    6-6   245.0
# 134      T.J.     Warren  Phoenix Suns    12.0       SF  22.0    6-8   230.0
#
#                   College
# 132                   NaN
# 133                 Texas
# 134  North Carolina State

# %%
## Concat
n23 = pd.concat([n2, n3])
n23
# Out:
#       firstName   lastName  Number Position Height  Weight  \
# 34         Jose   Calderon     3.0       PG    6-3   200.0
# 35   Cleanthony      Early    11.0       SF    6-8   210.0
# 36     Langston   Galloway     2.0       SG    6-2   200.0
# 37       Jerian      Grant    13.0       PG    6-4   195.0
# 132       Mirza  Teletovic    35.0       PF    6-9   242.0
# 133        P.J.     Tucker    17.0       SF    6-6   245.0
# 134        T.J.     Warren    12.0       SF    6-8   230.0
#
#                   College     Salary          Team   Age
# 34                    NaN  7402812.0           NaN   NaN
# 35          Wichita State   845059.0           NaN   NaN
# 36         Saint Joseph's   845059.0           NaN   NaN
# 37             Notre Dame  1572360.0           NaN   NaN
# 132                   NaN        NaN  Phoenix Suns  30.0
# 133                 Texas        NaN  Phoenix Suns  31.0
# 134  North Carolina State        NaN  Phoenix Suns  22.0

# %%
pd.concat([n3, n2])
# Out:
#       firstName   lastName          Team  Number Position   Age Height  \
# 132       Mirza  Teletovic  Phoenix Suns    35.0       PF  30.0    6-9
# 133        P.J.     Tucker  Phoenix Suns    17.0       SF  31.0    6-6
# 134        T.J.     Warren  Phoenix Suns    12.0       SF  22.0    6-8
# 34         Jose   Calderon           NaN     3.0       PG   NaN    6-3
# 35   Cleanthony      Early           NaN    11.0       SF   NaN    6-8
# 36     Langston   Galloway           NaN     2.0       SG   NaN    6-2
# 37       Jerian      Grant           NaN    13.0       PG   NaN    6-4
#
#      Weight               College     Salary
# 132   242.0                   NaN        NaN
# 133   245.0                 Texas        NaN
# 134   230.0  North Carolina State        NaN
# 34    200.0                   NaN  7402812.0
# 35    210.0         Wichita State   845059.0
# 36    200.0        Saint Joseph's   845059.0
# 37    195.0            Notre Dame  1572360.0

# %%
n2.append(n3)
# Out:
#       firstName   lastName  Number Position Height  Weight  \
# 34         Jose   Calderon     3.0       PG    6-3   200.0
# 35   Cleanthony      Early    11.0       SF    6-8   210.0
# 36     Langston   Galloway     2.0       SG    6-2   200.0
# 37       Jerian      Grant    13.0       PG    6-4   195.0
# 132       Mirza  Teletovic    35.0       PF    6-9   242.0
# 133        P.J.     Tucker    17.0       SF    6-6   245.0
# 134        T.J.     Warren    12.0       SF    6-8   230.0
#
#                   College     Salary          Team   Age
# 34                    NaN  7402812.0           NaN   NaN
# 35          Wichita State   845059.0           NaN   NaN
# 36         Saint Joseph's   845059.0           NaN   NaN
# 37             Notre Dame  1572360.0           NaN   NaN
# 132                   NaN        NaN  Phoenix Suns  30.0
# 133                 Texas        NaN  Phoenix Suns  31.0
# 134  North Carolina State        NaN  Phoenix Suns  22.0

# %%
# pd.concat?

# %%
pd.concat([n2, n3], axis = 1)
# Out:
#       firstName  lastName  Number Position Height  Weight         College  \
# 34         Jose  Calderon     3.0       PG    6-3   200.0             NaN
# 35   Cleanthony     Early    11.0       SF    6-8   210.0   Wichita State
# 36     Langston  Galloway     2.0       SG    6-2   200.0  Saint Joseph's
# 37       Jerian     Grant    13.0       PG    6-4   195.0      Notre Dame
# 132         NaN       NaN     NaN      NaN    NaN     NaN             NaN
# 133         NaN       NaN     NaN      NaN    NaN     NaN             NaN
# 134         NaN       NaN     NaN      NaN    NaN     NaN             NaN
#
#         Salary firstName   lastName          Team  Number Position   Age  \
# 34   7402812.0       NaN        NaN           NaN     NaN      NaN   NaN
# 35    845059.0       NaN        NaN           NaN     NaN      NaN   NaN
# 36    845059.0       NaN        NaN           NaN     NaN      NaN   NaN
# 37   1572360.0       NaN        NaN           NaN     NaN      NaN   NaN
# ...

# %%
n23
# Out:
#       firstName   lastName  Number Position Height  Weight  \
# 34         Jose   Calderon     3.0       PG    6-3   200.0
# 35   Cleanthony      Early    11.0       SF    6-8   210.0
# 36     Langston   Galloway     2.0       SG    6-2   200.0
# 37       Jerian      Grant    13.0       PG    6-4   195.0
# 132       Mirza  Teletovic    35.0       PF    6-9   242.0
# 133        P.J.     Tucker    17.0       SF    6-6   245.0
# 134        T.J.     Warren    12.0       SF    6-8   230.0
#
#                   College     Salary          Team   Age
# 34                    NaN  7402812.0           NaN   NaN
# 35          Wichita State   845059.0           NaN   NaN
# 36         Saint Joseph's   845059.0           NaN   NaN
# 37             Notre Dame  1572360.0           NaN   NaN
# 132                   NaN        NaN  Phoenix Suns  30.0
# 133                 Texas        NaN  Phoenix Suns  31.0
# 134  North Carolina State        NaN  Phoenix Suns  22.0

# %%
n231 = n23[['Number', 'College']]
n232 = n23[['Position', 'Salary']].drop(index = [132, 35])

# %%
n231
# Out:
#      Number               College
# 34      3.0                   NaN
# 35     11.0         Wichita State
# 36      2.0        Saint Joseph's
# 37     13.0            Notre Dame
# 132    35.0                   NaN
# 133    17.0                 Texas
# 134    12.0  North Carolina State

# %%
n232
# Out:
#     Position     Salary
# 34        PG  7402812.0
# 36        SG   845059.0
# 37        PG  1572360.0
# 133       SF        NaN
# 134       SF        NaN

# %%
n32 = pd.concat([n231, n232])
n32
# Out:
#      Number         College Position     Salary
# 34      3.0             NaN      NaN        NaN
# 35     11.0   Wichita State      NaN        NaN
# 36      2.0  Saint Joseph's      NaN        NaN
# 37     13.0      Notre Dame      NaN        NaN
# 132    35.0             NaN      NaN        NaN
# ..      ...             ...      ...        ...
# 34      NaN             NaN       PG  7402812.0
# 36      NaN             NaN       SG   845059.0
# 37      NaN             NaN       PG  1572360.0
# 133     NaN             NaN       SF        NaN
# 134     NaN             NaN       SF        NaN
#
# [12 rows x 4 columns]

# %%
n323 = pd.concat([n231, n232], axis = 1)
n323
# Out:
#      Number               College Position     Salary
# 34      3.0                   NaN       PG  7402812.0
# 35     11.0         Wichita State      NaN        NaN
# 36      2.0        Saint Joseph's       SG   845059.0
# 37     13.0            Notre Dame       PG  1572360.0
# 132    35.0                   NaN      NaN        NaN
# 133    17.0                 Texas       SF        NaN
# 134    12.0  North Carolina State       SF        NaN

# %%
a = 85
b = 'MITS'
c = 'C'
d = 785.0
dic = dict(zip(n323.columns, [a,b,c,d]))
dic
# Out:
# {'Number': 85, 'College': 'MITS', 'Position': 'C', 'Salary': 785.0}

# %%
n323.iloc[[-1]]
# Out:
#      Number               College Position  Salary
# 134    12.0  North Carolina State       SF     NaN

# %%
list(n323.iloc[[-1]].index)
# Out:
# [134]

# %%
dicdf = pd.DataFrame([dic], index = [n323.iloc[[-1]].index + 1])
dicdf
# Out:
#      Number College Position  Salary
# 135      85    MITS        C   785.0

# %%
pd.DataFrame?

# %%
n323
# Out:
#      Number               College Position     Salary
# 34      3.0                   NaN       PG  7402812.0
# 35     11.0         Wichita State      NaN        NaN
# 36      2.0        Saint Joseph's       SG   845059.0
# 37     13.0            Notre Dame       PG  1572360.0
# 132    35.0                   NaN      NaN        NaN
# 133    17.0                 Texas       SF        NaN
# 134    12.0  North Carolina State       SF        NaN

# %%
n323.loc[len(n323)] = [a,b,c,d]

# %%
n323
# Out:
#      Number               College Position     Salary
# 34      3.0                   NaN       PG  7402812.0
# 35     11.0         Wichita State      NaN        NaN
# 36      2.0        Saint Joseph's       SG   845059.0
# 37     13.0            Notre Dame       PG  1572360.0
# 132    35.0                   NaN      NaN        NaN
# 133    17.0                 Texas       SF        NaN
# 134    12.0  North Carolina State       SF        NaN
# 7      85.0                  MITS        C      785.0

# %%
n323.iloc[[-1]].index[0] + 1
# Out:
# 8

# %%
n323
# Out:
#      Number               College Position     Salary
# 34      3.0                   NaN       PG  7402812.0
# 35     11.0         Wichita State      NaN        NaN
# 36      2.0        Saint Joseph's       SG   845059.0
# 37     13.0            Notre Dame       PG  1572360.0
# 132    35.0                   NaN      NaN        NaN
# 133    17.0                 Texas       SF        NaN
# 134    12.0  North Carolina State       SF        NaN
# 7      85.0                  MITS        C      785.0

# %%
n323.drop(index = n323.tail(1).index, inplace = True)

# %%
n323
# Out:
#      Number               College Position     Salary
# 34      3.0                   NaN       PG  7402812.0
# 35     11.0         Wichita State      NaN        NaN
# 36      2.0        Saint Joseph's       SG   845059.0
# 37     13.0            Notre Dame       PG  1572360.0
# 132    35.0                   NaN      NaN        NaN
# 133    17.0                 Texas       SF        NaN
# 134    12.0  North Carolina State       SF        NaN

# %%
(n323.tail(1).index)+1
# Out:
# Int64Index([135], dtype='int64')

# %%
n323.loc[n323.iloc[[-1]].index[0] + 1] = [a,b,c,d]

# %%
n323
# Out:
#      Number               College Position     Salary
# 34      3.0                   NaN       PG  7402812.0
# 35     11.0         Wichita State      NaN        NaN
# 36      2.0        Saint Joseph's       SG   845059.0
# 37     13.0            Notre Dame       PG  1572360.0
# 132    35.0                   NaN      NaN        NaN
# 133    17.0                 Texas       SF        NaN
# 134    12.0  North Carolina State       SF        NaN
# 135    85.0                  MITS        C      785.0

# %%
n
# Out:
#     firstName lastName            Team  Number Position   Age Height  Weight  \
# 0       Avery  Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1         Jae  Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2        John  Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3        R.J.   Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4       Jonas  Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..        ...      ...             ...     ...      ...   ...    ...     ...
# 451     Chris  Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452      Trey    Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 454      Raul     Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455     Tibor   Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456      Jeff   Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# ...

# %% [markdown]
# ### Combining data in pandas

# %%
a = [2,5,8,1,9,3,8,0, 4, 6]
b = [4,7,0,2,4,1,9,-1]
x = pd.Series(a)
y = pd.Series(b)

z = x.combine(y, (lambda a1, b1: a1 if a1>b1 else b1))
list(z)
# Out:
# [4.0, 7.0, 8.0, 2.0, 9.0, 3.0, 9.0, 0.0, nan, nan]

# %%
x.combine(y, (lambda a1, b1: a1 + b1))
# Out:
# 0     6.0
# 1    12.0
# 2     8.0
# 3     3.0
# 4    13.0
# 5     4.0
# 6    17.0
# 7    -1.0
# 8     NaN
# 9     NaN
# dtype: float64

# %% [markdown]
# ## Merge in pandas

# %%
d1 = {'id':[1,2,3,4,5], 
      'Name': list('ABCDE'), 
      'subject':['sub1','sub2','sub4','sub6','sub5']}

d2 = {'id':[1,2,3,4,5], 
      'Name': list('FGHIJ'), 
      'subject':['sub2','sub4','sub3','sub6','sub5']}

df1 = pd.DataFrame(d1)
df2 = pd.DataFrame(d2)

# %%
# pd.read_csv?

# %%
df1
# Out:
#    id Name subject
# 0   1    A    sub1
# 1   2    B    sub2
# 2   3    C    sub4
# 3   4    D    sub6
# 4   5    E    sub5

# %%
df2
# Out:
#    id Name subject
# 0   1    F    sub2
# 1   2    G    sub4
# 2   3    H    sub3
# 3   4    I    sub6
# 4   5    J    sub5

# %%
pd.merge(df1, df2)
# Out:
# Empty DataFrame
# Columns: [id, Name, subject]
# Index: []

# %%
pd.merge(df1, df2, on = 'id')
# Out:
#    id Name_x subject_x Name_y subject_y
# 0   1      A      sub1      F      sub2
# 1   2      B      sub2      G      sub4
# 2   3      C      sub4      H      sub3
# 3   4      D      sub6      I      sub6
# 4   5      E      sub5      J      sub5

# %%
pd.merge(df1, df2, on = 'Name')
# Out:
# Empty DataFrame
# Columns: [id_x, Name, subject_x, id_y, subject_y]
# Index: []

# %%
pd.merge(df1, df2, on = 'subject')
# Out:
#    id_x Name_x subject  id_y Name_y
# 0     2      B    sub2     1      F
# 1     3      C    sub4     2      G
# 2     4      D    sub6     4      I
# 3     5      E    sub5     5      J

# %%
pd.merge(df1, df2, on = 'subject', how = 'inner')
# Out:
#    id_x Name_x subject  id_y Name_y
# 0     2      B    sub2     1      F
# 1     3      C    sub4     2      G
# 2     4      D    sub6     4      I
# 3     5      E    sub5     5      J

# %%
pd.merge(df1, df2, on = 'subject', how = 'outer')
# Out:
#    id_x Name_x subject  id_y Name_y
# 0   1.0      A    sub1   NaN    NaN
# 1   2.0      B    sub2   1.0      F
# 2   3.0      C    sub4   2.0      G
# 3   4.0      D    sub6   4.0      I
# 4   5.0      E    sub5   5.0      J
# 5   NaN    NaN    sub3   3.0      H

# %%
pd.merge(df1, df2, on = 'id', how = 'outer')
# Out:
#    id Name_x subject_x Name_y subject_y
# 0   1      A      sub1      F      sub2
# 1   2      B      sub2      G      sub4
# 2   3      C      sub4      H      sub3
# 3   4      D      sub6      I      sub6
# 4   5      E      sub5      J      sub5

# %%
pd.merge(df1, df2, on = 'Name', how = 'outer')
# Out:
#    id_x Name subject_x  id_y subject_y
# 0   1.0    A      sub1   NaN       NaN
# 1   2.0    B      sub2   NaN       NaN
# 2   3.0    C      sub4   NaN       NaN
# 3   4.0    D      sub6   NaN       NaN
# 4   5.0    E      sub5   NaN       NaN
# 5   NaN    F       NaN   1.0      sub2
# 6   NaN    G       NaN   2.0      sub4
# 7   NaN    H       NaN   3.0      sub3
# 8   NaN    I       NaN   4.0      sub6
# 9   NaN    J       NaN   5.0      sub5

# %%
pd.merge(df1, df2, on = 'subject', how = 'left')
# Out:
#    id_x Name_x subject  id_y Name_y
# 0     1      A    sub1   NaN    NaN
# 1     2      B    sub2   1.0      F
# 2     3      C    sub4   2.0      G
# 3     4      D    sub6   4.0      I
# 4     5      E    sub5   5.0      J

# %%
# a = some.how()
pd.merge(df1, df2, on = 'subject', how = 'right')
# Out:
#    id_x Name_x subject  id_y Name_y
# 0   2.0      B    sub2     1      F
# 1   3.0      C    sub4     2      G
# 2   NaN    NaN    sub3     3      H
# 3   4.0      D    sub6     4      I
# 4   5.0      E    sub5     5      J

# %%
pd.merge(df1, df2, on = ['id','subject'], how = 'inner')
# Out:
#    id Name_x subject Name_y
# 0   4      D    sub6      I
# 1   5      E    sub5      J

# %%
df1
# Out:
#    id Name subject
# 0   1    A    sub1
# 1   2    B    sub2
# 2   3    C    sub4
# 3   4    D    sub6
# 4   5    E    sub5

# %%
df2
# Out:
#    id Name subject
# 0   1    F    sub2
# 1   2    G    sub4
# 2   3    H    sub3
# 3   4    I    sub6
# 4   5    J    sub5

# %% [markdown]
# ## Apply in pandas

# %%
n
# Out:
#     firstName lastName            Team  Number Position   Age Height  Weight  \
# 0       Avery  Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1         Jae  Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2        John  Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3        R.J.   Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4       Jonas  Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..        ...      ...             ...     ...      ...   ...    ...     ...
# 451     Chris  Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452      Trey    Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 454      Raul     Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455     Tibor   Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456      Jeff   Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# ...

# %%
hi = lambda a: 1 if a == 'PG' else 0
n3 = n['Position'].apply(hi)
n3
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 451    0
# 452    0
# 454    1
# 455    0
# 456    0
# Name: Position, Length: 451, dtype: int64

# %%
n['PosNum'] = n3
n
# Out:
#     firstName lastName            Team  Number Position   Age Height  Weight  \
# 0       Avery  Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1         Jae  Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2        John  Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3        R.J.   Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4       Jonas  Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..        ...      ...             ...     ...      ...   ...    ...     ...
# 451     Chris  Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452      Trey    Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 454      Raul     Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455     Tibor   Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456      Jeff   Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary  PosNum
# ...

# %%
n['Position']
# Out:
# 0      PG
# 1      SF
# 2      SG
# 3      SG
# 4      PF
#        ..
# 451    SF
# 452    PF
# 454    PG
# 455     C
# 456     C
# Name: Position, Length: 451, dtype: object

# %%
n.Position
# Out:
# 0      PG
# 1      SF
# 2      SG
# 3      SG
# 4      PF
#        ..
# 451    SF
# 452    PF
# 454    PG
# 455     C
# 456     C
# Name: Position, Length: 451, dtype: object

# %%
n['Position'].unique()
# Out:
# array(['PG', 'SF', 'SG', 'PF', 'C'], dtype=object)

# %%
n
# Out:
#     firstName lastName            Team  Number Position   Age Height  Weight  \
# 0       Avery  Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1         Jae  Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2        John  Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3        R.J.   Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4       Jonas  Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..        ...      ...             ...     ...      ...   ...    ...     ...
# 451     Chris  Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452      Trey    Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 454      Raul     Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455     Tibor   Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456      Jeff   Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary  PosNum
# ...

# %% [markdown]
# ### Feature Engineering
# Feature engineering is a machine learning technique that leverages existing data to create new variables that aren't in the training set.

# %%
def hello(a):
    import numpy as np
    if   a == 'PG': return 1
    elif a == 'PF': return 2
    elif a == 'SG': return 3
    elif a == 'SF': return 4
    elif a == 'C' : return 5
    else:           return np.nan
    
n['PosNum2'] = n.Position.apply(hello)
n
# Out:
#     firstName lastName            Team  Number Position   Age Height  Weight  \
# 0       Avery  Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1         Jae  Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2        John  Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3        R.J.   Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4       Jonas  Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..        ...      ...             ...     ...      ...   ...    ...     ...
# 451     Chris  Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452      Trey    Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 454      Raul     Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455     Tibor   Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456      Jeff   Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
# ...

# %%
n.drop(columns = 'PosNum', inplace = True)

# %%
n
# Out:
#     firstName lastName            Team  Number Position   Age Height  Weight  \
# 0       Avery  Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1         Jae  Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2        John  Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3        R.J.   Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4       Jonas  Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..        ...      ...             ...     ...      ...   ...    ...     ...
# 451     Chris  Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452      Trey    Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 454      Raul     Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455     Tibor   Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456      Jeff   Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary  PosNum2
# ...

# %%
n.rename(columns = {'PosNum2':'PosNum'}, inplace = True)

# %%
n
# Out:
#     firstName lastName            Team  Number Position   Age Height  Weight  \
# 0       Avery  Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1         Jae  Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2        John  Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3        R.J.   Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4       Jonas  Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..        ...      ...             ...     ...      ...   ...    ...     ...
# 451     Chris  Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452      Trey    Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 454      Raul     Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455     Tibor   Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456      Jeff   Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary  PosNum
# ...

# %%
# def hello(a):
#     import numpy as np
#     if   a == 'PG': return 1
#     elif a == 'PF': return 2
#     elif a == 'SG': return 3
#     elif a == 'SF': return 4
#     elif a == 'C' : return 5
#     else:           return np.nan
    
# n['PosNum2'] = n.Position.apply(hello)


# d = {'PG':1, 'PF':2, 'SG':3, 'SF':4, 'C':5}
# hello = lambda a: d[a]
# n['PosNum2'] = n.Position.apply(hello)
# n


# n['PosNum2'] = n.Position.apply(lambda a: {'PG':1, 'PF':2, 'SG':3, 'SF':4, 'C':5}[a])
# n

# %% [markdown]
# ## Descriptive Statistics in pandas

# %%
n1
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
n1.count()
# Out:
# Name        457
# Team        457
# Number      457
# Position    457
# Age         457
# Height      457
# Weight      457
# College     373
# Salary      446
# dtype: int64

# %%
n1.notnull()
# Out:
#      Name  Team  Number  Position   Age  Height  Weight  College  Salary
# 0    True  True    True      True  True    True    True     True    True
# 1    True  True    True      True  True    True    True     True    True
# 2    True  True    True      True  True    True    True     True   False
# 3    True  True    True      True  True    True    True     True    True
# 4    True  True    True      True  True    True    True    False    True
# ..    ...   ...     ...       ...   ...     ...     ...      ...     ...
# 452  True  True    True      True  True    True    True     True    True
# 453  True  True    True      True  True    True    True     True    True
# 454  True  True    True      True  True    True    True    False    True
# 455  True  True    True      True  True    True    True    False    True
# 456  True  True    True      True  True    True    True     True    True
#
# [457 rows x 9 columns]

# %%
n1.notnull().sum()
# Out:
# Name        457
# Team        457
# Number      457
# Position    457
# Age         457
# Height      457
# Weight      457
# College     373
# Salary      446
# dtype: int64

# %%
n1.isnull()
# Out:
#       Name   Team  Number  Position    Age  Height  Weight  College  Salary
# 0    False  False   False     False  False   False   False    False   False
# 1    False  False   False     False  False   False   False    False   False
# 2    False  False   False     False  False   False   False    False    True
# 3    False  False   False     False  False   False   False    False   False
# 4    False  False   False     False  False   False   False     True   False
# ..     ...    ...     ...       ...    ...     ...     ...      ...     ...
# 452  False  False   False     False  False   False   False    False   False
# 453  False  False   False     False  False   False   False    False   False
# 454  False  False   False     False  False   False   False     True   False
# 455  False  False   False     False  False   False   False     True   False
# 456  False  False   False     False  False   False   False    False   False
#
# [457 rows x 9 columns]

# %%
n1.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
n1.isnull().sum()/len(n1)*100
# Out:
# Name         0.000000
# Team         0.000000
# Number       0.000000
# Position     0.000000
# Age          0.000000
# Height       0.000000
# Weight       0.000000
# College     18.380744
# Salary       2.407002
# dtype: float64

# %% [markdown]
# ## Filtering

# %%
n1
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
import numpy as np
a = np.array([1,2,3,7,9,4,8,4])
b = a.reshape((2,4))
b
# Out:
# array([[1, 2, 3, 7],
#        [9, 4, 8, 4]])

# %%
b[0][2]    # Indexing
# Out:
# 3

# %%
b[0,2]     # Integer Array indexing
# Out:
# 3

# %%
b[b%2==0]
# Out:
# array([2, 4, 8, 4])

# %%
b[b == 3]
# Out:
# array([3])

# %%
n1[(n1['Position'] == 'PG') | (n1.Position == 'SG')]   # n1[n1.Position == 'PG']
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 8     Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9     Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 444     Alec Burks       Utah Jazz    10.0       SG  24.0    6-6   214.0
# 445     Dante Exum       Utah Jazz    11.0       PG  20.0    6-6   190.0
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
n1[(n1['Position'] == 'PG') & (n1.Team == 'Boston Celtics')]
# Out:
#              Name            Team  Number Position   Age Height  Weight  \
# 0   Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 8    Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9    Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
# 11  Isaiah Thomas  Boston Celtics     4.0       PG  27.0    5-9   185.0
#
#            College     Salary
# 0            Texas  7730337.0
# 8       Louisville  1824360.0
# 9   Oklahoma State  3431040.0
# 11      Washington  6912869.0

# %%
n1[(n1.Team == 'Boston Celtics')]
# Out:
#                Name            Team  Number Position   Age Height  Weight  \
# 0     Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1       Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2      John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3       R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4     Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..              ...             ...     ...      ...   ...    ...     ...
# 10  Jared Sullinger  Boston Celtics     7.0        C  24.0    6-9   260.0
# 11    Isaiah Thomas  Boston Celtics     4.0       PG  27.0    5-9   185.0
# 12      Evan Turner  Boston Celtics    11.0       SG  27.0    6-7   220.0
# 13      James Young  Boston Celtics    13.0       SG  20.0    6-6   215.0
# 14     Tyler Zeller  Boston Celtics    44.0        C  26.0    7-0   253.0
#
#               College     Salary
# 0               Texas  7730337.0
# ...

# %%
n1[(n1['Position'] == 'PG') ^ (n1.Team == 'Boston Celtics')]
# Out:
#               Name                    Team  Number Position   Age Height  \
# 1      Jae Crowder          Boston Celtics    99.0       SF  25.0    6-6
# 2     John Holland          Boston Celtics    30.0       SG  27.0    6-5
# 3      R.J. Hunter          Boston Celtics    28.0       SG  22.0    6-5
# 4    Jonas Jerebko          Boston Celtics     8.0       PF  29.0   6-10
# 5     Amir Johnson          Boston Celtics    90.0       PF  29.0    6-9
# ..             ...                     ...     ...      ...   ...    ...
# 440  Brian Roberts  Portland Trail Blazers     2.0       PG  30.0    6-1
# 443     Trey Burke               Utah Jazz     3.0       PG  23.0    6-1
# 445     Dante Exum               Utah Jazz    11.0       PG  20.0    6-6
# 453   Shelvin Mack               Utah Jazz     8.0       PG  26.0    6-3
# 454      Raul Neto               Utah Jazz    25.0       PG  24.0    6-1
#
#      Weight            College      Salary
# 1     235.0          Marquette   6796117.0
# ...

# %%
n1[~(n1.Team == 'Boston Celtics')]
# Out:
#                         Name           Team  Number Position   Age Height  \
# 15          Bojan Bogdanovic  Brooklyn Nets    44.0       SG  27.0    6-8
# 16              Markel Brown  Brooklyn Nets    22.0       SG  24.0    6-3
# 17           Wayne Ellington  Brooklyn Nets    21.0       SG  28.0    6-4
# 18   Rondae Hollis-Jefferson  Brooklyn Nets    24.0       SG  21.0    6-7
# 19              Jarrett Jack  Brooklyn Nets     2.0       PG  32.0    6-3
# ..                       ...            ...     ...      ...   ...    ...
# 452               Trey Lyles      Utah Jazz    41.0       PF  20.0   6-10
# 453             Shelvin Mack      Utah Jazz     8.0       PG  26.0    6-3
# 454                Raul Neto      Utah Jazz    25.0       PG  24.0    6-1
# 455             Tibor Pleiss      Utah Jazz    21.0        C  26.0    7-3
# 456              Jeff Withey      Utah Jazz    24.0        C  26.0    7-0
#
#      Weight         College     Salary
# 15    216.0             NaN  3425510.0
# ...

# %%
n1[(n1.Team == 'Boston Celtics')].Salary.mean()
# Out:
# 4181504.8571428573

# %%
n1[(n1.Position == 'PG') & (n1.Age > 30)].Salary.mean()
# Out:
# 4989297.05882353

# %%
n1[n1.Salary == np.nan]
# Out:
# Empty DataFrame
# Columns: [Name, Team, Number, Position, Age, Height, Weight, College, Salary]
# Index: []

# %%
n1[n1.Salary.isnull()]
# Out:
#                Name                    Team  Number Position   Age Height  \
# 2      John Holland          Boston Celtics    30.0       SG  27.0    6-5
# 46      Elton Brand      Philadelphia 76ers    42.0       PF  37.0    6-9
# 171   Dahntay Jones     Cleveland Cavaliers    30.0       SG  35.0    6-6
# 264   Jordan Farmar       Memphis Grizzlies     4.0       PG  29.0    6-2
# 269    Ray McCallum       Memphis Grizzlies     5.0       PG  24.0    6-3
# ..              ...                     ...     ...      ...   ...    ...
# 273  Alex Stepheson       Memphis Grizzlies    35.0       PF  28.0   6-10
# 350   Briante Weber              Miami Heat    12.0       PG  23.0    6-2
# 353   Dorell Wright              Miami Heat    11.0       SF  30.0    6-9
# 397    Axel Toupane          Denver Nuggets     6.0       SG  23.0    6-7
# 409      Greg Smith  Minnesota Timberwolves     4.0       PF  25.0   6-10
#
#      Weight                College  Salary
# ...

# %%
n2 = n1.copy()

# %%
n2[n2.Salary.isnull()].index
# Out:
# Int64Index([2, 46, 171, 264, 269, 270, 273, 350, 353, 397, 409], dtype='int64')

# %%
list(n1[n1.Salary.isnull()].index)
# Out:
# [2, 46, 171, 264, 269, 270, 273, 350, 353, 397, 409]

# %%
n1[n1.Salary.isnull()].index.tolist()
# Out:
# [2, 46, 171, 264, 269, 270, 273, 350, 353, 397, 409]

# %%
n1.drop(index = list(n1[n1.Salary.isnull()].index), inplace = True)

# %%
n1
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5     Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College      Salary
# 0            Texas   7730337.0
# ...

# %%
len(n2) - len(n1)
# Out:
# 11

# %%
n1.isnull().sum()/len(n1)*100
# Out:
# Name         0.00000
# Team         0.00000
# Number       0.00000
# Position     0.00000
# Age          0.00000
# Height       0.00000
# Weight       0.00000
# College     18.38565
# Salary       0.00000
# dtype: float64

# %%
# s = 'hello'
# s.tolist()

# %%
n2
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
n2["NameRank"] = n2["Name"].rank()
n2["SalRank"] = n2.Salary.rank()

# %%
n2
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary  NameRank  SalRank
# ...

# %%
n2[n2.SalRank == 1]
# Out:
#                       Name             Team  Number Position   Age Height  \
# 32  Thanasis Antetokounmpo  New York Knicks    43.0       SF  23.0    6-7
#
#     Weight College   Salary  NameRank  SalRank
# 32   205.0     NaN  30888.0     415.0      1.0

# %%
import pandas as pd
import numpy

a = numpy.array(["foo", "foo", "foo", "foo", "bar", "bar", "bar", "bar", "foo", "foo", "foo"], dtype=object)
b = numpy.array(["one", "one", "one", "two", "one", "one", "one", "two", "two", "two", "one"], dtype=object)
ab = pd.crosstab(a, b, rownames=['a'], colnames=['b'])
ab
# Out:
# b    one  two
# a
# bar    3    1
# foo    4    3

# %%
a
# Out:
# array(['foo', 'foo', 'foo', 'foo', 'bar', 'bar', 'bar', 'bar', 'foo',
#        'foo', 'foo'], dtype=object)

# %%
b
# Out:
# array(['one', 'one', 'one', 'two', 'one', 'one', 'one', 'two', 'two',
#        'two', 'one'], dtype=object)

# %%
n2
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary  NameRank  SalRank
# ...

# %%
n2.Position.unique()
# Out:
# array(['PG', 'SF', 'SG', 'PF', 'C'], dtype=object)

# %%
n2.Position.count()
# Out:
# 457

# %%
n2.Position.value_counts()
# Out:
# SG    102
# PF    100
# PG     92
# SF     85
# C      78
# Name: Position, dtype: int64

# %%
n2.Position.unique()
# Out:
# array(['PG', 'SF', 'SG', 'PF', 'C'], dtype=object)

# %%
pd.crosstab(n2.Team, n2.Age).T
# Out:
# Team  Atlanta Hawks  Boston Celtics  Brooklyn Nets  Charlotte Hornets  \
# Age
# 19.0              0               0              0                  0
# 20.0              0               1              0                  0
# 21.0              0               1              2                  1
# 22.0              1               3              1                  1
# 23.0              0               0              1                  2
# ...             ...             ...            ...                ...
# 36.0              0               0              0                  0
# 37.0              0               0              0                  0
# 38.0              0               0              0                  0
# 39.0              0               0              0                  0
# 40.0              0               0              0                  0
#
# Team  Chicago Bulls  Cleveland Cavaliers  Dallas Mavericks  Denver Nuggets  \
# Age
# ...

# %%
n2[['Team', 'Age']].value_counts?
# Out:
# Object `value_counts` not found.

# %%
n2[['Team', 'Age']].value_counts

# %%
n2[['Team', 'Age']].value_counts
# Out:
# <bound method DataFrame.value_counts of                Team   Age
# 0    Boston Celtics  25.0
# 1    Boston Celtics  25.0
# 2    Boston Celtics  27.0
# 3    Boston Celtics  22.0
# 4    Boston Celtics  29.0
# ..              ...   ...
# 452       Utah Jazz  20.0
# 453       Utah Jazz  26.0
# 454       Utah Jazz  24.0
# 455       Utah Jazz  26.0
# 456       Utah Jazz  26.0
#
# [457 rows x 2 columns]>

# %%
n2[['Team', 'Age']].value_counts()
# Out:
# Team                   Age
# Philadelphia 76ers     22.0    5
# Oklahoma City Thunder  24.0    5
# Utah Jazz              26.0    5
# Detroit Pistons        23.0    4
# Milwaukee Bucks        21.0    4
#                               ..
# Los Angeles Lakers     33.0    1
#                        36.0    1
#                        37.0    1
# Memphis Grizzlies      21.0    1
# Washington Wizards     34.0    1
# Length: 288, dtype: int64

# %%
n2.Position.value_counts()
# Out:
# SG    102
# PF    100
# PG     92
# SF     85
# C      78
# Name: Position, dtype: int64

# %%
n2.Position.value_counts(normalize = True)*100
# Out:
# SG    22.319475
# PF    21.881838
# PG    20.131291
# SF    18.599562
# C     17.067834
# Name: Position, dtype: float64

# %%
n3 = n2.copy()

# %%
pd.cut?

# %%
pd.cut(n3.Age, bins=3, right=True)
# Out:
# 0      (18.979, 26.0]
# 1      (18.979, 26.0]
# 2        (26.0, 33.0]
# 3      (18.979, 26.0]
# 4        (26.0, 33.0]
#             ...
# 452    (18.979, 26.0]
# 453    (18.979, 26.0]
# 454    (18.979, 26.0]
# 455    (18.979, 26.0]
# 456    (18.979, 26.0]
# Name: Age, Length: 457, dtype: category
# Categories (3, interval[float64]): [(18.979, 26.0] < (26.0, 33.0] < (33.0, 40.0]]

# %%
pd.cut(n3.Age, bins=3, right=False)
# Out:
# 0      [19.0, 26.0)
# 1      [19.0, 26.0)
# 2      [26.0, 33.0)
# 3      [19.0, 26.0)
# 4      [26.0, 33.0)
#            ...
# 452    [19.0, 26.0)
# 453    [26.0, 33.0)
# 454    [19.0, 26.0)
# 455    [26.0, 33.0)
# 456    [26.0, 33.0)
# Name: Age, Length: 457, dtype: category
# Categories (3, interval[float64]): [[19.0, 26.0) < [26.0, 33.0) < [33.0, 40.021)]

# %%
pd.cut(n3.Age, bins=3, right=False, retbins = True)
# Out:
# (0      [19.0, 26.0)
#  1      [19.0, 26.0)
#  2      [26.0, 33.0)
#  3      [19.0, 26.0)
#  4      [26.0, 33.0)
#             ...
#  452    [19.0, 26.0)
#  453    [26.0, 33.0)
#  454    [19.0, 26.0)
#  455    [26.0, 33.0)
#  456    [26.0, 33.0)
#  Name: Age, Length: 457, dtype: category
#  Categories (3, interval[float64]): [[19.0, 26.0) < [26.0, 33.0) < [33.0, 40.021)],
#  array([19.   , 26.   , 33.   , 40.021]))

# %%
n3.Age
# Out:
# 0      25.0
# 1      25.0
# 2      27.0
# 3      22.0
# 4      29.0
#        ...
# 452    20.0
# 453    26.0
# 454    24.0
# 455    26.0
# 456    26.0
# Name: Age, Length: 457, dtype: float64

# %%
pd.cut(n3.Age, bins=3, right=False)
# Out:
# 0      [19.0, 26.0)
# 1      [19.0, 26.0)
# 2      [26.0, 33.0)
# 3      [19.0, 26.0)
# 4      [26.0, 33.0)
#            ...
# 452    [19.0, 26.0)
# 453    [26.0, 33.0)
# 454    [19.0, 26.0)
# 455    [26.0, 33.0)
# 456    [26.0, 33.0)
# Name: Age, Length: 457, dtype: category
# Categories (3, interval[float64]): [[19.0, 26.0) < [26.0, 33.0) < [33.0, 40.021)]

# %%
# pd.cut?

# %%
# pd.qcut?

# %%
pd.qcut(n3.Age, 10)
# Out:
# 0        (24.0, 25.0]
# 1        (24.0, 25.0]
# 2        (26.0, 27.0]
# 3      (18.999, 22.0]
# 4        (27.0, 29.0]
#             ...
# 452    (18.999, 22.0]
# 453      (25.0, 26.0]
# 454      (23.0, 24.0]
# 455      (25.0, 26.0]
# 456      (25.0, 26.0]
# Name: Age, Length: 457, dtype: category
# Categories (10, interval[float64]): [(18.999, 22.0] < (22.0, 23.0] < (23.0, 24.0] < (24.0, 25.0] ... (27.0, 29.0] < (29.0, 30.0] < (30.0, 33.0] < (33.0, 40.0]]

# %%
import pandas as pd

data = {
  "Brand": ["Ford", "Ford", "Ford"],
  "Model": ["Sierra", "F-150", "Mustang"],
  "Typ" : ["2.0 GL", "Raptor", ["Mach-E", "Mach-1"]]
}
df = pd.DataFrame(data)

newdf = df.explode('Typ')

# %%
newdf
# Out:
#   Brand    Model     Typ
# 0  Ford   Sierra  2.0 GL
# 1  Ford    F-150  Raptor
# 2  Ford  Mustang  Mach-E
# 2  Ford  Mustang  Mach-1

# %%
df
# Out:
#   Brand    Model               Typ
# 0  Ford   Sierra            2.0 GL
# 1  Ford    F-150            Raptor
# 2  Ford  Mustang  [Mach-E, Mach-1]

# %%
# df.explode?

# %%
newdf.unstack(4)
# Out:
# Brand  0       Ford
#        1       Ford
#        2       Ford
#        2       Ford
# Model  0     Sierra
#              ...
#        2    Mustang
# Typ    0     2.0 GL
#        1     Raptor
#        2     Mach-E
#        2     Mach-1
# Length: 12, dtype: object

# %%
newdf
# Out:
#   Brand    Model     Typ
# 0  Ford   Sierra  2.0 GL
# 1  Ford    F-150  Raptor
# 2  Ford  Mustang  Mach-E
# 2  Ford  Mustang  Mach-1

# %%
n
# Out:
#     firstName lastName            Team  Number Position   Age Height  Weight  \
# 0       Avery  Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1         Jae  Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2        John  Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3        R.J.   Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4       Jonas  Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..        ...      ...             ...     ...      ...   ...    ...     ...
# 451     Chris  Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452      Trey    Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 454      Raul     Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455     Tibor   Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456      Jeff   Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary  PosNum
# ...

# %%
n.corr()
# Out:
#           Number       Age    Weight    Salary    PosNum
# Number  1.000000  0.032678  0.207802 -0.112132  0.121533
# Age     0.032678  1.000000  0.083829  0.208325  0.017527
# Weight  0.207802  0.083829  1.000000  0.135970  0.555504
# Salary -0.112132  0.208325  0.135970  1.000000  0.046228
# PosNum  0.121533  0.017527  0.555504  0.046228  1.000000

# %%
# n.corr?

# %%
n.corr().unstack()
# Out:
# Number  Number    1.000000
#         Age       0.032678
#         Weight    0.207802
#         Salary   -0.112132
#         PosNum    0.121533
#                     ...
# PosNum  Number    0.121533
#         Age       0.017527
#         Weight    0.555504
#         Salary    0.046228
#         PosNum    1.000000
# Length: 25, dtype: float64

# %%
n.corr().unstack().Number
# Out:
# Number    1.000000
# Age       0.032678
# Weight    0.207802
# Salary   -0.112132
# PosNum    0.121533
# dtype: float64

# %%
n
# Out:
#     firstName lastName            Team  Number Position   Age Height  Weight  \
# 0       Avery  Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1         Jae  Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2        John  Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3        R.J.   Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4       Jonas  Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..        ...      ...             ...     ...      ...   ...    ...     ...
# 451     Chris  Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452      Trey    Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 454      Raul     Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455     Tibor   Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456      Jeff   Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary  PosNum
# ...

# %%
n[n.Age > 30]
# Out:
#     firstName  lastName                    Team  Number Position   Age Height  \
# 19    Jarrett      Jack           Brooklyn Nets     2.0       PG  32.0    6-3
# 31        Lou  Amundson         New York Knicks    17.0       PF  33.0    6-9
# 33    Carmelo   Anthony         New York Knicks     7.0       SF  32.0    6-8
# 34       Jose  Calderon         New York Knicks     3.0       PG  34.0    6-3
# 43      Sasha   Vujacic         New York Knicks    18.0       SG  32.0    6-7
# ..        ...       ...                     ...     ...      ...   ...    ...
# 406  Tayshaun    Prince  Minnesota Timberwolves    12.0       SF  36.0    6-9
# 413      Nick  Collison   Oklahoma City Thunder     4.0       PF  35.0   6-10
# 415     Randy      Foye   Oklahoma City Thunder     6.0       SG  32.0    6-4
# 420      Nazr  Mohammed   Oklahoma City Thunder    13.0        C  38.0   6-10
# 434     Chris     Kaman  Portland Trail Blazers    35.0        C  34.0    7-0
#
# ...

# %%
n.query("Age>30")
# Out:
#     firstName  lastName                    Team  Number Position   Age Height  \
# 19    Jarrett      Jack           Brooklyn Nets     2.0       PG  32.0    6-3
# 31        Lou  Amundson         New York Knicks    17.0       PF  33.0    6-9
# 33    Carmelo   Anthony         New York Knicks     7.0       SF  32.0    6-8
# 34       Jose  Calderon         New York Knicks     3.0       PG  34.0    6-3
# 43      Sasha   Vujacic         New York Knicks    18.0       SG  32.0    6-7
# ..        ...       ...                     ...     ...      ...   ...    ...
# 406  Tayshaun    Prince  Minnesota Timberwolves    12.0       SF  36.0    6-9
# 413      Nick  Collison   Oklahoma City Thunder     4.0       PF  35.0   6-10
# 415     Randy      Foye   Oklahoma City Thunder     6.0       SG  32.0    6-4
# 420      Nazr  Mohammed   Oklahoma City Thunder    13.0        C  38.0   6-10
# 434     Chris     Kaman  Portland Trail Blazers    35.0        C  34.0    7-0
#
# ...
