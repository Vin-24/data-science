# %%
import pandas as pd
import numpy as np
n=pd.read_csv(r'E:\vinay\dataset\India-Tourism-Statistics-2021-Table-5.2.3.csv')
n
# Out:
#           Circle                              Name of the Monument   \
# 0           Agra                                          Taj Mahal
# 1           Agra                                          Agra Fort
# 2           Agra                                     Fatehpur Sikri
# 3           Agra                                Akbar Tomb Sikandra
# 4           Agra                               Mariam tomb Sikandra
# ..           ...                                                ...
# 173    Amaravati                                    Nagarjuna Kunda
# 174    Amaravati                               Chandragiri Monument
# 175    Amaravati  Buddhist Remains on hill top at Guntupalli, W....
# 176        Total                                              Total
# 177  Grand Total                                        Grand Total
#
#      Domestic-2019-20  Foreign-2019-20  Domestic-2020-21  Foreign-2020-21  \
# 0             4429710           645415           1259892             9034
# ...

# %%
n.isnull().count()
# Out:
# Circle                               178
# Name of the Monument                 178
# Domestic-2019-20                     178
# Foreign-2019-20                      178
# Domestic-2020-21                     178
# Foreign-2020-21                      178
# % Growth 2021-21/2019-20-Domestic    178
# % Growth 2021-21/2019-20-Foreign     178
# dtype: int64

# %%
n.head()
# Out:
#   Circle Name of the Monument   Domestic-2019-20  Foreign-2019-20  \
# 0   Agra             Taj Mahal           4429710           645415
# 1   Agra             Agra Fort           1627154           386522
# 2   Agra        Fatehpur Sikri            454376           184751
# 3   Agra   Akbar Tomb Sikandra            229270            19625
# 4   Agra  Mariam tomb Sikandra             22517              414
#
#    Domestic-2020-21  Foreign-2020-21  % Growth 2021-21/2019-20-Domestic  \
# 0           1259892             9034                             -71.56
# 1            371242             2810                             -77.18
# 2            107835              574                             -76.27
# 3             99509              321                             -56.60
# 4              9765               31                             -56.63
#
#    % Growth 2021-21/2019-20-Foreign
# 0                            -98.60
# 1                            -99.27
# ...

# %%
n.head(26)
# Out:
#      Circle                            Name of the Monument   \
# 0      Agra                                        Taj Mahal
# 1      Agra                                        Agra Fort
# 2      Agra                                   Fatehpur Sikri
# 3      Agra                              Akbar Tomb Sikandra
# 4      Agra                             Mariam tomb Sikandra
# 5      Agra                            Itimad-ud-Daulah-Tomb
# 6      Agra                                         Ram Bagh
# 7      Agra                                      Mehtab Bagh
# 8      Agra                                        Mausoleum
# 9     Total                                            Total
# 10  Lucknow                              Site of Sahet mahet
# 11  Lucknow                               Residency Building
# 12  Lucknow                              Piprahwa & Ganwaria
# 13    Total                                            Total
# ...

# %%
n.columns
# Out:
# Index(['Circle', 'Name of the Monument ', 'Domestic-2019-20',
#        'Foreign-2019-20', 'Domestic-2020-21', 'Foreign-2020-21',
#        '% Growth 2021-21/2019-20-Domestic',
#        '% Growth 2021-21/2019-20-Foreign'],
#       dtype='object')

# %%
n1=n
n1=n1.drop(columns='Circle')
n1
# Out:
#                                  Name of the Monument   Domestic-2019-20  \
# 0                                            Taj Mahal           4429710
# 1                                            Agra Fort           1627154
# 2                                       Fatehpur Sikri            454376
# 3                                  Akbar Tomb Sikandra            229270
# 4                                 Mariam tomb Sikandra             22517
# ..                                                 ...               ...
# 173                                    Nagarjuna Kunda             19762
# 174                               Chandragiri Monument            103489
# 175  Buddhist Remains on hill top at Guntupalli, W....             22353
# 176                                              Total            262949
# 177                                        Grand Total          43607075
#
#      Foreign-2019-20  Domestic-2020-21  Foreign-2020-21  \
# ...

# %%
len(n)
# Out:
# 178

# %%
n.iloc[:10, 2:5]
# Out:
#    Domestic-2019-20  Foreign-2019-20  Domestic-2020-21
# 0           4429710           645415           1259892
# 1           1627154           386522            371242
# 2            454376           184751            107835
# 3            229270            19625             99509
# 4             22517              414              9765
# 5            132800            82692             41016
# 6             84051              355             18599
# 7            178574            62325             62652
# 8            474462            12536             91185
# 9           7632914          1394635           2061695

# %%
n
# Out:
#           Circle                              Name of the Monument   \
# 0           Agra                                          Taj Mahal
# 1           Agra                                          Agra Fort
# 2           Agra                                     Fatehpur Sikri
# 3           Agra                                Akbar Tomb Sikandra
# 4           Agra                               Mariam tomb Sikandra
# ..           ...                                                ...
# 173    Amaravati                                    Nagarjuna Kunda
# 174    Amaravati                               Chandragiri Monument
# 175    Amaravati  Buddhist Remains on hill top at Guntupalli, W....
# 176        Total                                              Total
# 177  Grand Total                                        Grand Total
#
#      Domestic-2019-20  Foreign-2019-20  Domestic-2020-21  Foreign-2020-21  \
# 0             4429710           645415           1259892             9034
# ...

# %%
n.dtypes
# Out:
# Circle                                object
# Name of the Monument                  object
# Domestic-2019-20                       int64
# Foreign-2019-20                        int64
# Domestic-2020-21                       int64
# Foreign-2020-21                        int64
# % Growth 2021-21/2019-20-Domestic    float64
# % Growth 2021-21/2019-20-Foreign     float64
# dtype: object

# %%
n.columns
# Out:
# Index(['Circle', 'Name of the Monument ', 'Domestic-2019-20',
#        'Foreign-2019-20', 'Domestic-2020-21', 'Foreign-2020-21',
#        '% Growth 2021-21/2019-20-Domestic',
#        '% Growth 2021-21/2019-20-Foreign'],
#       dtype='object')

# %%
n[n['Foreign-2019-20'] > 2137]
# Out:
#           Circle             Name of the Monument   Domestic-2019-20  \
# 0           Agra                         Taj Mahal           4429710
# 1           Agra                         Agra Fort           1627154
# 2           Agra                    Fatehpur Sikri            454376
# 3           Agra               Akbar Tomb Sikandra            229270
# 5           Agra             Itimad-ud-Daulah-Tomb            132800
# ..           ...                               ...               ...
# 157        Patna  Ancient site of Vaishali, Kolhua             89631
# 158        Patna      Excavated Remains at Nalanda            437506
# 161        Total                             Total            910849
# 166        Total                             Total            164745
# 177  Grand Total                       Grand Total          43607075
#
#      Foreign-2019-20  Domestic-2020-21  Foreign-2020-21  \
# 0             645415           1259892             9034
# ...

# %%
strObj = 'geeksforgeeks'

print(repr(strObj))
print(strObj)
# Out:
# 'geeksforgeeks'
# geeksforgeeks

# %%
n.query('`Foreign-2019-20` > 2137')
# Out:
#           Circle             Name of the Monument   Domestic-2019-20  \
# 0           Agra                         Taj Mahal           4429710
# 1           Agra                         Agra Fort           1627154
# 2           Agra                    Fatehpur Sikri            454376
# 3           Agra               Akbar Tomb Sikandra            229270
# 5           Agra             Itimad-ud-Daulah-Tomb            132800
# ..           ...                               ...               ...
# 157        Patna  Ancient site of Vaishali, Kolhua             89631
# 158        Patna      Excavated Remains at Nalanda            437506
# 161        Total                             Total            910849
# 166        Total                             Total            164745
# 177  Grand Total                       Grand Total          43607075
#
#      Foreign-2019-20  Domestic-2020-21  Foreign-2020-21  \
# 0             645415           1259892             9034
# ...

# %%
n.loc[[2, 4, 5, 25], ['Circle', 'Domestic-2019-20', 'Foreign-2019-20']]
# Out:
#    Circle  Domestic-2019-20  Foreign-2019-20
# 2    Agra            454376           184751
# 4    Agra             22517              414
# 5    Agra            132800            82692
# 25  Total            847571           106938

# %%
n.tail(5)
# Out:
#           Circle                              Name of the Monument   \
# 173    Amaravati                                    Nagarjuna Kunda
# 174    Amaravati                               Chandragiri Monument
# 175    Amaravati  Buddhist Remains on hill top at Guntupalli, W....
# 176        Total                                              Total
# 177  Grand Total                                        Grand Total
#
#      Domestic-2019-20  Foreign-2019-20  Domestic-2020-21  Foreign-2020-21  \
# 173             19762               35                 0                0
# 174            103489              109             51113               38
# 175             22353               85             10219               10
# 176            262949             1008            116120              137
# 177          43607075          2756561          13153076           415859
#
#      % Growth 2021-21/2019-20-Domestic  % Growth 2021-21/2019-20-Foreign
# ...

# %%
n.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 8 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Circle                             178 non-null    object
#  1   Name of the Monument               178 non-null    object
#  2   Domestic-2019-20                   178 non-null    int64
#  3   Foreign-2019-20                    178 non-null    int64
#  4   Domestic-2020-21                   178 non-null    int64
#  5   Foreign-2020-21                    178 non-null    int64
#  6   % Growth 2021-21/2019-20-Domestic  177 non-null    float64
#  7   % Growth 2021-21/2019-20-Foreign   176 non-null    float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 11.2+ KB

# %%
n.describe()
# Out:
#        Domestic-2019-20  Foreign-2019-20  Domestic-2020-21  Foreign-2020-21  \
# count      1.780000e+02     1.780000e+02      1.780000e+02       178.000000
# mean       7.349507e+05     4.645889e+04      2.216811e+05      7008.859551
# std        3.375224e+06     2.412842e+05      1.009087e+06     40252.182392
# min        5.300000e+02     0.000000e+00      0.000000e+00         0.000000
# 25%        4.586950e+04     1.697500e+02      1.427275e+04        14.500000
# 50%        1.765070e+05     1.747000e+03      5.747650e+04       101.500000
# 75%        4.641905e+05     1.242850e+04      1.524880e+05       340.000000
# max        4.360708e+07     2.756561e+06      1.315308e+07    415859.000000
#
#        % Growth 2021-21/2019-20-Domestic  % Growth 2021-21/2019-20-Foreign
# count                         177.000000                        176.000000
# mean                          -28.225367                        937.419148
# ...

# %%
n["Foreign-2019-20"].unique()
# Out:
# array([ 645415,  386522,  184751,   19625,     414,   82692,     355,
#          62325,   12536, 1394635,   13628,    3367,    3098,   20093,
#             32,     137,      50,     705,     924,      85,     114,
#            954,  100590,       9,    5186,  106938,     728,   79355,
#            241,    3305,   83629,   53422,    1736,    1063,   56221,
#             94,      46,     188,     460,     645,    5259,     340,
#           7032,      42,     272,    2017,    2427,    1884,    3986,
#           7744,       4,      89,     741,     736,   19942,      18,
#          41741,   41801,    3849,    6758,    4310,    1683,    1290,
#             91,   17981,   27006,      56,   27062,   14016,    8653,
#          10719,    1095,   34483,      52,    1723,    1775,     505,
#             27,     532,     168,     796,     142,    1106,    1948,
#           3732,    3816,    7907,   17403,    5294,    2489,     506,
# ...

# %%
n["Foreign-2019-20"].nunique()
# Out:
# 168

# %%
n.isnull()
# Out:
#      Circle  Name of the Monument   Domestic-2019-20  Foreign-2019-20  \
# 0     False                  False             False            False
# 1     False                  False             False            False
# 2     False                  False             False            False
# 3     False                  False             False            False
# 4     False                  False             False            False
# ..      ...                    ...               ...              ...
# 173   False                  False             False            False
# 174   False                  False             False            False
# 175   False                  False             False            False
# 176   False                  False             False            False
# 177   False                  False             False            False
#
#      Domestic-2020-21  Foreign-2020-21  % Growth 2021-21/2019-20-Domestic  \
# ...

# %%
n2= n[n["Foreign-2019-20"].isnull()]
n2
# Out:
# Empty DataFrame
# Columns: [Circle, Name of the Monument , Domestic-2019-20, Foreign-2019-20, Domestic-2020-21, Foreign-2020-21, % Growth 2021-21/2019-20-Domestic, % Growth 2021-21/2019-20-Foreign]
# Index: []

# %%
n.sort_values("Foreign-2019-20")
# Out:
#           Circle                             Name of the Monument   \
# 167     Srinagar       Palace Complex at Ramnagar, Distt. Udhampur
# 50        Bhopal  Buddhist cave no 01 to 51 Dhamnar, Tehsil Garoth
# 169     Srinagar   Group of Temples at kiramchi, District Udhampur
# 123        Delhi                                  Sultanghari Tomb
# 23       Sarnath                                  Tomb of Lal Khan
# ..           ...                                               ...
# 1           Agra                                         Agra Fort
# 133        Total                                             Total
# 0           Agra                                         Taj Mahal
# 9          Total                                             Total
# 177  Grand Total                                       Grand Total
#
#      Domestic-2019-20  Foreign-2019-20  Domestic-2020-21  Foreign-2020-21  \
# 167              6610                0              2129                0
# ...

# %%
n.value_counts("Circle")
# Out:
# Circle
# Total              33
# Mumbai             13
# Bhopal             11
# Delhi              11
# Agra                9
# Tiruchirappalli     7
# Aurangabad          6
# Dharwad             6
# Sarnath             6
# Amaravati           5
# Bhubaneswar         5
# Patna               5
# Guwahati            5
# Thrissur            4
# Jhansi              4
# Vadodara            4
# Banglore            4
# Jaipur              3
# Chennai             3
# Srinagar            3
# Rajkot              3
# Jabalpur            3
# Lucknow             3
# Jodhpur             3
# Hyderabad           3
# Hampi               2
# Nagpur              2
# Shimla              2
# Kolkata             2
# Chandigarh          2
# Raiganj             2
# Grand Total         1
# Raipur              1
# Leh                 1
# Goa                 1
# dtype: int64

# %%
n.nlargest(10, "Foreign-2019-20")
# Out:
#           Circle         Name of the Monument   Domestic-2019-20  \
# 177  Grand Total                   Grand Total          43607075
# 9          Total                         Total           7632914
# 0           Agra                     Taj Mahal           4429710
# 133        Total                         Total           6158331
# 1           Agra                     Agra Fort           1627154
# 127        Delhi                   Qutub Minar           2048146
# 126        Delhi                  Humayun Tomb            658318
# 2           Agra                Fatehpur Sikri            454376
# 25         Total                         Total            847571
# 22       Sarnath  Excavated Remains at sarnath            485309
#
#      Foreign-2019-20  Domestic-2020-21  Foreign-2020-21  \
# 177          2756561          13153076           415859
# 9            1394635           2061695            14099
# 0             645415           1259892             9034
# ...

# %%
n.nsmallest(10, "Foreign-2019-20")
# Out:
#        Circle                              Name of the Monument   \
# 167  Srinagar        Palace Complex at Ramnagar, Distt. Udhampur
# 50     Bhopal   Buddhist cave no 01 to 51 Dhamnar, Tehsil Garoth
# 169  Srinagar    Group of Temples at kiramchi, District Udhampur
# 123     Delhi                                   Sultanghari Tomb
# 23    Sarnath                                   Tomb of Lal Khan
# 116    Nagpur                                     Gawilgarh Fort
# 55   Jabalpur  Ancient Site and Adamgrah rock shelter, Kalamd...
# 78    Kolkata                                       Metcelf-Hall
# 14     Jhansi               Gupta Temple & Varah Temple, Deogarh
# 168  Srinagar   Avantiswamin Temple, Avantipur, District Pulwama
#
#      Domestic-2019-20  Foreign-2019-20  Domestic-2020-21  Foreign-2020-21  \
# 167              6610                0              2129                0
# 50              32578                4             12303               13
# ...

# %%
n3=n.iloc[0:10, :].copy()
n3
# Out:
#   Circle  Name of the Monument   Domestic-2019-20  Foreign-2019-20  \
# 0   Agra              Taj Mahal           4429710           645415
# 1   Agra              Agra Fort           1627154           386522
# 2   Agra         Fatehpur Sikri            454376           184751
# 3   Agra    Akbar Tomb Sikandra            229270            19625
# 4   Agra   Mariam tomb Sikandra             22517              414
# 5   Agra  Itimad-ud-Daulah-Tomb            132800            82692
# 6   Agra               Ram Bagh             84051              355
# 7   Agra            Mehtab Bagh            178574            62325
# 8   Agra              Mausoleum            474462            12536
# 9  Total                  Total           7632914          1394635
#
#    Domestic-2020-21  Foreign-2020-21  % Growth 2021-21/2019-20-Domestic  \
# 0           1259892             9034                             -71.56
# 1            371242             2810                             -77.18
# ...

# %%
n1.rename(columns = {"Domestic-2019-20": "Dom_19/20",
                      "Foreign-2019-20": "For_19/20",
                      "Foreign-2020-21": "For_20/21", 
                    "Domestic-2020-21": "Dom_20/21"},
           inplace=True)
n1
# Out:
#                                  Name of the Monument     Dom_19   For_19  \
# 0                                            Taj Mahal   4429710   645415
# 1                                            Agra Fort   1627154   386522
# 2                                       Fatehpur Sikri    454376   184751
# 3                                  Akbar Tomb Sikandra    229270    19625
# 4                                 Mariam tomb Sikandra     22517      414
# ..                                                 ...       ...      ...
# 173                                    Nagarjuna Kunda     19762       35
# 174                               Chandragiri Monument    103489      109
# 175  Buddhist Remains on hill top at Guntupalli, W....     22353       85
# 176                                              Total    262949     1008
# 177                                        Grand Total  43607075  2756561
#
#      Dom_20/21  For_20/21  % Growth 2021-21/2019-20-Domestic  \
# ...

# %%
#n1.corr?
#n1[["Domestic-2019-20", "Domestic-2020-21"]].corr()#(higher the number higher the dependencies on each other lesser the value lesser the dependencies)
#n.corr().unstack()
n.corr().unstack()
# Out:
# C:\Users\Legion\AppData\Local\Temp\ipykernel_25872\2386728936.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   n.corr().unstack()
# Domestic-2019-20                   Domestic-2019-20                     1.000000
#                                    Foreign-2019-20                      0.931943
#                                    Domestic-2020-21                     0.994342
#                                    Foreign-2020-21                      0.744288
#                                    % Growth 2021-21/2019-20-Domestic   -0.027125
#                                    % Growth 2021-21/2019-20-Foreign    -0.027671
# Foreign-2019-20                    Domestic-2019-20                     0.931943
#                                    Foreign-2019-20                      1.000000
# ...

# %%
n.dtypes
# Out:
# Circle                                object
# Name of the Monument                  object
# Domestic-2019-20                       int64
# Foreign-2019-20                        int64
# Domestic-2020-21                       int64
# Foreign-2020-21                        int64
# % Growth 2021-21/2019-20-Domestic    float64
# % Growth 2021-21/2019-20-Foreign     float64
# dtype: object

# %%
n.select_dtypes(include='int64')
# Out:
#      Domestic-2019-20  Foreign-2019-20  Domestic-2020-21  Foreign-2020-21
# 0             4429710           645415           1259892             9034
# 1             1627154           386522            371242             2810
# 2              454376           184751            107835              574
# 3              229270            19625             99509              321
# 4               22517              414              9765               31
# ..                ...              ...               ...              ...
# 173             19762               35                 0                0
# 174            103489              109             51113               38
# 175             22353               85             10219               10
# 176            262949             1008            116120              137
# 177          43607075          2756561          13153076           415859
#
# [178 rows x 4 columns]

# %%
n.select_dtypes(exclude='int64')
# Out:
#           Circle                              Name of the Monument   \
# 0           Agra                                          Taj Mahal
# 1           Agra                                          Agra Fort
# 2           Agra                                     Fatehpur Sikri
# 3           Agra                                Akbar Tomb Sikandra
# 4           Agra                               Mariam tomb Sikandra
# ..           ...                                                ...
# 173    Amaravati                                    Nagarjuna Kunda
# 174    Amaravati                               Chandragiri Monument
# 175    Amaravati  Buddhist Remains on hill top at Guntupalli, W....
# 176        Total                                              Total
# 177  Grand Total                                        Grand Total
#
#      % Growth 2021-21/2019-20-Domestic  % Growth 2021-21/2019-20-Foreign
# 0                               -71.56                            -98.60
# ...

# %%
n[['% Growth 2021-21/2019-20-Domestic', '% Growth 2021-21/2019-20-Foreign']].cumsum()
# Out:
#      % Growth 2021-21/2019-20-Domestic  % Growth 2021-21/2019-20-Foreign
# 0                               -71.56                            -98.60
# 1                              -148.74                           -197.87
# 2                              -225.01                           -297.56
# 3                              -281.61                           -395.92
# 4                              -338.24                           -488.43
# ..                                 ...                               ...
# 173                                NaN                               NaN
# 174                           -4815.93                         165245.33
# 175                           -4870.21                         165157.09
# 176                           -4926.05                         165070.68
# 177                           -4995.89                         164985.77
#
# [178 rows x 2 columns]

# %%
n['Foreign-2019-20'].where(n['Foreign-2019-20']>500, 0)
# Out:
# 0       645415
# 1       386522
# 2       184751
# 3        19625
# 4            0
#         ...
# 173          0
# 174          0
# 175          0
# 176       1008
# 177    2756561
# Name: Foreign-2019-20, Length: 178, dtype: int64

# %%
n['rank_calc'] = n["Foreign-2019-20"].rank() 
n
# Out:
#           Circle                              Name of the Monument   \
# 0           Agra                                          Taj Mahal
# 1           Agra                                          Agra Fort
# 2           Agra                                     Fatehpur Sikri
# 3           Agra                                Akbar Tomb Sikandra
# 4           Agra                               Mariam tomb Sikandra
# ..           ...                                                ...
# 173    Amaravati                                    Nagarjuna Kunda
# 174    Amaravati                               Chandragiri Monument
# 175    Amaravati  Buddhist Remains on hill top at Guntupalli, W....
# 176        Total                                              Total
# 177  Grand Total                                        Grand Total
#
#      Domestic-2019-20  Foreign-2019-20  Domestic-2020-21  Foreign-2020-21  \
# 0             4429710           645415           1259892             9034
# ...

# %%
n1.replace("Agra", "Agra City")
# Out:
#           Circle                              Name of the Monument   \
# 0      Agra City                                          Taj Mahal
# 1      Agra City                                          Agra Fort
# 2      Agra City                                     Fatehpur Sikri
# 3      Agra City                                Akbar Tomb Sikandra
# 4      Agra City                               Mariam tomb Sikandra
# ..           ...                                                ...
# 173    Amaravati                                    Nagarjuna Kunda
# 174    Amaravati                               Chandragiri Monument
# 175    Amaravati  Buddhist Remains on hill top at Guntupalli, W....
# 176        Total                                              Total
# 177  Grand Total                                        Grand Total
#
#      Domestic-2019-20  Foreign-2019-20  Domestic-2020-21  Foreign-2020-21  \
# 0             4429710           645415           1259892             9034
# ...

# %%
n1.groupby("Circle")['Foreign-2019-20'].sum()
# Out:
# Circle
# Agra               1394635
# Amaravati             1008
# Aurangabad           56402
# Banglore             34483
# Bhopal               19942
# Bhubaneswar           9249
# Chandigarh             118
# Chennai              56221
# Delhi               581350
# Dharwad              17981
# Goa                   8104
# Grand Total        2756561
# Guwahati              1557
# Hampi                27062
# Hyderabad            28652
# Jabalpur             41801
# Jaipur               88692
# Jhansi                 924
# Jodhpur              26494
# Kolkata                532
# Leh                   5671
# Lucknow              20093
# Mumbai               73371
# Nagpur                  76
# Patna                40661
# Raiganj               1775
# Raipur                  96
# Rajkot                1106
# Sarnath             106938
# Shimla                3467
# Srinagar                36
# Thrissur             83629
# Tiruchirappalli       7032
# Total              2756561
# ...

# %%
n['Domestic-2020-21'].pct_change()
# Out:
# 0             NaN
# 1       -0.705338
# 2       -0.709529
# 3       -0.077211
# 4       -0.901868
#           ...
# 173     -1.000000
# 174           inf
# 175     -0.800070
# 176     10.363147
# 177    112.271409
# Name: Domestic-2020-21, Length: 178, dtype: float64

# %%
n.count(0)
# Out:
# Circle                               178
# Name of the Monument                 178
# Domestic-2019-20                     178
# Foreign-2019-20                      178
# Domestic-2020-21                     178
# Foreign-2020-21                      178
# % Growth 2021-21/2019-20-Domestic    177
# % Growth 2021-21/2019-20-Foreign     176
# rank_calc                            178
# dtype: int64

# %%
pd.crosstab(n['Domestic-2019-20'], n['Domestic-2020-21'])
# Out:
# Domestic-2020-21  0         5         8         13        29        58        \
# Domestic-2019-20
# 530                      0         0         0         0         0         0
# 605                      0         0         0         0         0         0
# 1348                     0         0         0         0         0         0
# 1596                     0         0         1         0         0         0
# 1782                     0         0         0         0         0         0
# ...                    ...       ...       ...       ...       ...       ...
# 3941141                  0         0         0         0         0         0
# 4429710                  0         0         0         0         0         0
# 6158331                  0         0         0         0         0         0
# 7632914                  0         0         0         0         0         0
# 43607075                 0         0         0         0         0         0
#
# ...

# %%
pd.qcut(n['Domestic-2020-21'], q = 5)
# Out:
# 0      (195459.6, 13153076.0]
# 1      (195459.6, 13153076.0]
# 2         (87273.2, 195459.6]
# 3         (87273.2, 195459.6]
# 4           (-0.001, 11416.2]
#                 ...
# 173         (-0.001, 11416.2]
# 174        (41342.4, 87273.2]
# 175         (-0.001, 11416.2]
# 176       (87273.2, 195459.6]
# 177    (195459.6, 13153076.0]
# Name: Domestic-2020-21, Length: 178, dtype: category
# Categories (5, interval[float64, right]): [(-0.001, 11416.2] < (11416.2, 41342.4] < (41342.4, 87273.2] < (87273.2, 195459.6] < (195459.6, 13153076.0]]

# %%
pd.qcut(n['Domestic-2020-21'], q = 5).value_counts()
# Out:
# (-0.001, 11416.2]         36
# (41342.4, 87273.2]        36
# (195459.6, 13153076.0]    36
# (11416.2, 41342.4]        35
# (87273.2, 195459.6]       35
# Name: Domestic-2020-21, dtype: int64

# %%
pd.cut(n['Domestic-2020-21'], bins=5)
# Out:
# 0       (-13153.076, 2630615.2]
# 1       (-13153.076, 2630615.2]
# 2       (-13153.076, 2630615.2]
# 3       (-13153.076, 2630615.2]
# 4       (-13153.076, 2630615.2]
#                  ...
# 173     (-13153.076, 2630615.2]
# 174     (-13153.076, 2630615.2]
# 175     (-13153.076, 2630615.2]
# 176     (-13153.076, 2630615.2]
# 177    (10522460.8, 13153076.0]
# Name: Domestic-2020-21, Length: 178, dtype: category
# Categories (5, interval[float64, right]): [(-13153.076, 2630615.2] < (2630615.2, 5261230.4] < (5261230.4, 7891845.6] < (7891845.6, 10522460.8] < (10522460.8, 13153076.0]]

# %%
pd.cut(n['Domestic-2020-21'], bins=5).value_counts()
# Out:
# (-13153.076, 2630615.2]     177
# (10522460.8, 13153076.0]      1
# (2630615.2, 5261230.4]        0
# (5261230.4, 7891845.6]        0
# (7891845.6, 10522460.8]       0
# Name: Domestic-2020-21, dtype: int64
